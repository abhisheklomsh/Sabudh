# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # SF Salaries Exercise
#
# Welcome to a quick exercise for you to practice your pandas skills! We will be using the [SF Salaries Dataset](https://www.kaggle.com/kaggle/sf-salaries) from Kaggle! Just follow along and complete the tasks outlined in bold below. The tasks will get harder and harder as you go along.

# %% [markdown]
# ** Import pandas as pd.**

# %%
import pandas as pd

# %% [markdown]
# ** Read Salaries.csv as a dataframe called sal.**

# %%
data = pd.read_csv('Salaries.csv')

# %% [markdown]
# ** Check the head of the DataFrame. **

# %%
data.head(1000)
# Out:
#        Id          EmployeeName  \
# 0       1        NATHANIEL FORD
# 1       2          GARY JIMENEZ
# 2       3        ALBERT PARDINI
# 3       4     CHRISTOPHER CHONG
# 4       5       PATRICK GARDNER
# 5       6        DAVID SULLIVAN
# 6       7             ALSON LEE
# 7       8         DAVID KUSHNER
# 8       9        MICHAEL MORRIS
# 9      10    JOANNE HAYES-WHITE
# 10     11         ARTHUR KENNEY
# 11     12      PATRICIA JACKSON
# 12     13     EDWARD HARRINGTON
# 13     14           JOHN MARTIN
# 14     15        DAVID FRANKLIN
# 15     16       RICHARD CORRIEA
# 16     17              AMY HART
# 17     18        SEBASTIAN WONG
# 18     19            MARTY ROSS
# 19     20         ELLEN MOFFATT
# 20     21            VENUS AZAR
# 21     22          JUDY MELINEK
# 22     23         GEORGE GARCIA
# 23     24         VICTOR WYRSCH
# 24     25       JOSEPH DRISCOLL
# 25     26          GREGORY SUHR
# 26     27           JOHN HANLEY
# 27     28        RAYMOND GUZMAN
# 28     29        DENISE SCHMITT
# 29     30         MONICA FIELDS
# ..    ...                   ...
# 970   971          GABRIEL SHIN
# 971   972     MOJGAN YOUSEFKHAN
# 972   973         TERRY SMERDEL
# 973   974          MATTHEW LANE
# 974   975       LARRY CAMILLERI
# 975   976         DAVID ELLIOTT
# 976   977        DOUGLAS SPIKES
# 977   978       GABRIEL ALCARAZ
# 978   979      VALERIE MATTHEWS
# 979   980      EUGENE CLENDINEN
# 980   981         EDWARD BROWNE
# 981   982       WILLIAM WYCKOFF
# 982   983        CHARLES MC COY
# 983   984        MICHAEL HASTEY
# 984   985             PEIYUE HO
# 985   986         CAROL WOLTHER
# 986   987      KENNETH LOMBARDI
# 987   988           DANIEL COLE
# 988   989  DOUGLAS PRICE-HANSON
# 989   990           SUSAN OBATA
# 990   991      RICHARD THOMPSON
# 991   992         LOUIS ESPINDA
# 992   993        DAMEN TOLLIVER
# 993   994           GRACE SALUD
# 994   995       YUSUFU CAUNGULA
# 995   996    ANTIONETTE GRIFFIN
# 996   997         KATHERINE MAH
# 997   998   CHRISTINE DAVENPORT
# 998   999           ANNE HUGHES
# 999  1000            JOHN FAZIO
#
#                                              JobTitle    BasePay  OvertimePay  \
# 0      GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.00
# 1                     CAPTAIN III (POLICE DEPARTMENT)  155966.02    245131.88
# 2                     CAPTAIN III (POLICE DEPARTMENT)  212739.13    106088.18
# 3                WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00     56120.71
# 4        DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60      9737.00
# 5                           ASSISTANT DEPUTY CHIEF II  118602.00      8601.00
# 6                  BATTALION CHIEF, (FIRE DEPARTMENT)   92492.01     89062.90
# 7                      DEPUTY DIRECTOR OF INVESTMENTS  256576.96         0.00
# 8                  BATTALION CHIEF, (FIRE DEPARTMENT)  176932.64     86362.68
# 9              CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)  285262.00         0.00
# 10   ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)  194999.39     71344.88
# 11                    CAPTAIN III (POLICE DEPARTMENT)   99722.00     87082.62
# 12                        EXECUTIVE CONTRACT EMPLOYEE  294580.02         0.00
# 13                                  DEPARTMENT HEAD V  271329.03         0.00
# 14                 BATTALION CHIEF, (FIRE DEPARTMENT)  174872.64     74050.30
# 15                 COMMANDER III, (POLICE DEPARTMENT)  198778.01     73478.20
# 16                                  DEPARTMENT HEAD V  268604.57         0.00
# 17              CAPTAIN, EMERGENCYCY MEDICAL SERVICES  140546.87    119397.26
# 18                 BATTALION CHIEF, (FIRE DEPARTMENT)  168692.63     69626.12
# 19                         ASSISTANT MEDICAL EXAMINER  257510.59       880.16
# 20                         ASSISTANT MEDICAL EXAMINER  257510.48         0.00
# 21                         ASSISTANT MEDICAL EXAMINER  257510.44       377.21
# 22                          CAPTAIN, FIRE SUPPRESSION  140546.88     93200.58
# 23                 BATTALION CHIEF, (FIRE DEPARTMENT)  168692.63     77896.14
# 24                          CAPTAIN, FIRE SUPPRESSION  140546.86     97868.77
# 25                                    CHIEF OF POLICE  256470.41         0.00
# 26                          CAPTAIN, FIRE SUPPRESSION   92080.80     40008.00
# 27                 BATTALION CHIEF, (FIRE DEPARTMENT)  168692.59     80706.88
# 28               DEPUTY CHIEF III (POLICE DEPARTMENT)  261717.60         0.00
# 29       DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  246225.60         0.00
# ..                                                ...        ...          ...
# 970                                       FIREFIGHTER  105934.68     47640.85
# 971                          PRINCIPAL CIVIL ENGINEER  162362.78         0.00
# 972                       LIEUTENANT, FIRE DEPARTMENT  124863.62     31978.14
# 973                            FIRE FIGHTER PARAMEDIC  116781.05     45173.46
# 974                INSPECTOR III, (POLICE DEPARTMENT)   69076.00     21434.52
# 975                INSPECTOR III, (POLICE DEPARTMENT)  130457.96      9086.08
# 976                            FIRE FIGHTER PARAMEDIC  122404.98     32584.75
# 977                                 POLICE OFFICER II  110118.84     32981.90
# 978                INSPECTOR III, (POLICE DEPARTMENT)  130466.58     20619.01
# 979                                      MANAGER VIII  161479.27         0.00
# 980                                POLICE OFFICER III  112401.08      7430.89
# 981                                       FIREFIGHTER  105934.64     52697.70
# 982                       LIEUTENANT, FIRE DEPARTMENT  123105.00     31227.51
# 983                            FIRE FIGHTER PARAMEDIC  122405.00     32171.52
# 984                        DIAGNOSTIC IMAGING TECH II  103971.40     23945.61
# 985              ELECTRICAL TRANSIT SHOP SUPERVISOR I  109160.81     43092.79
# 986                         CAPTAIN, FIRE SUPPRESSION  135103.40     23598.47
# 987                  SERGEANT III (POLICE DEPARTMENT)  131715.02      5201.24
# 988                              PHYSICIAN SPECIALIST  159511.95         0.00
# 989                  SUPERVISING PHYSICIAN SPECIALIST  169941.65         0.00
# 990                             SENIOR DEPUTY SHERIFF   96252.08     64426.82
# 991                LIEUTENANT III (POLICE DEPARTMENT)  149050.78      6220.38
# 992                                       FIREFIGHTER  105934.64     54436.25
# 993                                     NURSE MANAGER  156312.00         0.00
# 994                                       FIREFIGHTER  105934.67     53551.86
# 995                         CLINICAL NURSE SPECIALIST  169572.08         0.00
# 996                         CLINICAL NURSE SPECIALIST  169572.06         0.00
# 997                         CLINICAL NURSE SPECIALIST  169572.05         0.00
# 998                         CLINICAL NURSE SPECIALIST  169572.01         0.00
# 999                         CLINICAL NURSE SPECIALIST  169572.00         0.00
#
#       OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  Notes  \
# 0    400184.25       NaN  567595.43         567595.43  2011    NaN
# 1    137811.38       NaN  538909.28         538909.28  2011    NaN
# 2     16452.60       NaN  335279.91         335279.91  2011    NaN
# 3    198306.90       NaN  332343.61         332343.61  2011    NaN
# 4    182234.59       NaN  326373.19         326373.19  2011    NaN
# 5    189082.74       NaN  316285.74         316285.74  2011    NaN
# 6    134426.14       NaN  315981.05         315981.05  2011    NaN
# 7     51322.50       NaN  307899.46         307899.46  2011    NaN
# 8     40132.23       NaN  303427.55         303427.55  2011    NaN
# 9     17115.73       NaN  302377.73         302377.73  2011    NaN
# 10    33149.90       NaN  299494.17         299494.17  2011    NaN
# 11   110804.30       NaN  297608.92         297608.92  2011    NaN
# 12        0.00       NaN  294580.02         294580.02  2011    NaN
# 13    21342.59       NaN  292671.62         292671.62  2011    NaN
# 14    37424.11       NaN  286347.05         286347.05  2011    NaN
# 15    13957.65       NaN  286213.86         286213.86  2011    NaN
# 16    16115.86       NaN  284720.43         284720.43  2011    NaN
# 17    18625.08       NaN  278569.21         278569.21  2011    NaN
# 20   San Francisco     NaN        26
# 21   San Francisco     NaN        26
# 22   San Francisco     NaN        25
# 23   San Francisco     NaN        34
# 24   San Francisco     NaN        25
# 25   San Francisco     NaN        15
# 26   San Francisco     NaN        25
# 27   San Francisco     NaN        34
# 28   San Francisco     NaN        36
# 29   San Francisco     NaN        44
# ..             ...     ...       ...
# 970  San Francisco     NaN        11
# 971  San Francisco     NaN        24
# 972  San Francisco     NaN        27
# 973  San Francisco     NaN        22
# 974  San Francisco     NaN        34
# 975  San Francisco     NaN        34
# 976  San Francisco     NaN        22
# 977  San Francisco     NaN        17
# 978  San Francisco     NaN        34
# 979  San Francisco     NaN        12
# 980  San Francisco     NaN        18
# 981  San Francisco     NaN        11
# 982  San Francisco     NaN        27
# 983  San Francisco     NaN        22
# 984  San Francisco     NaN        26
# 985  San Francisco     NaN        36
# 986  San Francisco     NaN        25
# 987  San Francisco     NaN        32
# 988  San Francisco     NaN        20
# 989  San Francisco     NaN        32
# 990  San Francisco     NaN        21
# 991  San Francisco     NaN        34
# 992  San Francisco     NaN        11
# 993  San Francisco     NaN        13
# 994  San Francisco     NaN        11
# 995  San Francisco     NaN        25
# 996  San Francisco     NaN        25
# 997  San Francisco     NaN        25
# 998  San Francisco     NaN        25
# 999  San Francisco     NaN        25
#
# [1000 rows x 14 columns]

# %% [markdown]
# ** Use the .info() method to find out how many entries there are.**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
# Id                  148654 non-null int64
# EmployeeName        148654 non-null object
# JobTitle            148654 non-null object
# BasePay             148045 non-null float64
# OvertimePay         148650 non-null float64
# OtherPay            148650 non-null float64
# Benefits            112491 non-null float64
# TotalPay            148654 non-null float64
# TotalPayBenefits    148654 non-null float64
# Year                148654 non-null int64
# Notes               0 non-null float64
# Agency              148654 non-null object
# Status              0 non-null float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %% [markdown]
# **What is the average BasePay ?**

# %%
data.BasePay.mean()
# Out:
# 66325.44884050643

# %% [markdown]
# ** What is the highest amount of OvertimePay in the dataset ? **

# %%
data.OvertimePay.max()
# Out:
# 245131.88

# %% [markdown]
# ** What is the job title of  JOSEPH DRISCOLL ? Note: Use all caps, otherwise you may get an answer that doesn't match up (there is also a lowercase Joseph Driscoll). **

# %%
data.loc[data['EmployeeName'] == 'JOSEPH DRISCOLL', 'JobTitle'].iloc[0]
# Out:
# 'CAPTAIN, FIRE SUPPRESSION'

# %% [markdown]
# ** How much does JOSEPH DRISCOLL make (including benefits)? **

# %%
data.loc[data['EmployeeName'] == 'JOSEPH DRISCOLL', 'TotalPayBenefits'].iloc[0]
# Out:
# 270324.91

# %% [markdown]
# ** What is the name of highest paid person (including benefits)?**

# %%
data.loc[data['TotalPayBenefits'] == data['TotalPayBenefits'].max(), 'EmployeeName'].iloc[0]
# Out:
# 'NATHANIEL FORD'

# %% [markdown]
# ** What is the name of lowest paid person (including benefits)? Do you notice something strange about how much he or she is paid?**

# %%
data.loc[data['TotalPayBenefits'] == data['TotalPayBenefits'].min(), ('EmployeeName','TotalPayBenefits')].iloc[0]
# Out:
# EmployeeName        Joe Lopez
# TotalPayBenefits      -618.13
# Name: 148653, dtype: object

# %% [markdown]
# ** What was the average (mean) BasePay of all employees per year? (2011-2014) ? **

# %%
for i in range(2011,2015):
    print(i," ",data[data['Year'] == i]['BasePay'].mean())
# Out:
# 2011   63595.956516774524
# 2012   65436.40685742255
# 2013   69630.0302164812
# 2014   66564.42192449933

# %% [markdown]
# ** How many unique job titles are there? **

# %%
len(data['JobTitle'].unique())
# Out:
# 2159

# %% [markdown]
# ** What are the top 5 most common jobs? **

# %%
data['JobTitle'].value_counts().head(5)
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %% [markdown]
# ** How many Job Titles were represented by only one person in 2013? (e.g. Job Titles with only one occurence in 2013?) **

# %%
data_2 = data[data['Year']==2013]['JobTitle'].value_counts().to_dict()

count=0

for keys,value in data_2.items(): 
    if value == 1:
        print(keys)
        count+=1
    
print(count)
count=0
# Out:
# Principal Real Property Ofc
# Asphalt Plant Supervisor 1
# Window Cleaner Supervisor
# Track Maint Supt, Muni Railway
# Bd/Comm Secretary 3
# Legislation Clerk
# Mgr Museum Security Services
# Animal Care Asst Supv
# Senior Plan Checker
# Court Reporter Coordinator
# Asst Dir of Clinical Svcs 1
# Junior Clerk Typist
# Special Assistant 15
# Assessor
# Feasibility Analyst, Port
# Sr Opers Mgr
# Assistant Director, Probate
# IS Technician Assistant
# Dir Emp Relations Div
# Mental Health Hearing Officer
# Wire Rope Cable Maint Sprv
# Airport Communications Officer
# Senior Assessment Clerk
# IS Trainer-Senior
# Pr Investigator, Tax Collector
# Port Director
# Law Librarian
# Assistant Sheriff
# Field Svcs Asst Supv
# Administrator, DPH
# Dir, Log Cabin Ranch (SFERS)
# Undersheriff
# Metalsmith
# Managing Attorney
# Forensic Toxicologist
# Area Sprv Parks, Squares & Fac
# Real Estate Devt. Mgr, SFMTA
# Media Programming Spec
# Braillist
# Cfdntal Sctry to City Atty
# Claims Process Clerk
# Asst Chf, Bur Clm Invest&Admin
# Supply Room Attendant
# Sheet Metal Wrk Supervisor 2
# Asst Superintendent Rec
# City Attorney
# Market Research Spec, Port
# Training Coordinator
# Employment & Training Spec 6
# Senior Food Service Supervisor
# Court Executive Officer
# Traffic Signal Operator
# Plumber Supervisor 2
# Mayoral Staff X
# Traf Signal Electrician Sup II
# Baker
# Special Assistant 21
# Mayoral Staff XII
# Dep Dir for Investments, Ret
# Senior Data Entry Operator
# Glazier Supervisor 1
# Principal Recreation Sprv
# Sctry, Juv Probation Comm
# Senior Offset Machine Operator
# Gen Mgr, Public Trnsp Dept
# Chief Electrical Inspector
# Airport Mechanical Maint Sprv
# Sr Medical Transcriber Typist
# Chief Deputy Adlt Probation Of
# Emergency Services Assistant
# Shade and Drapery Worker
# Sr General Utility Mechanic
# Assoc Musm Cnsrvt, AAM
# Painter Supervisor 2
# Mayor
# Controller
# Sheriff (SFERS)
# Assistant Inspector 2
# Statistician
# Municipal Stadium Groundskpr
# Chief Telephone Operator
# Sup Ct Admin Secretary
# Drug Court Coordinator
# Training Technician
# 202

# %% [markdown]
# ** How many people have the word Chief in their job title? (This is pretty tricky) **

# %%
import re
count = 0

for names in data.JobTitle:
    names=str(names.lower().split())
    if re.search("Chief".lower(),names):
        print(names)
        count+=1
print(count)
# Out:
# ['deputy', 'chief', 'of', 'department,(fire', 'department)']
# ['assistant', 'deputy', 'chief', 'ii']
# ['battalion', 'chief,', '(fire', 'department)']
# ['battalion', 'chief,', '(fire', 'department)']
# ['chief', 'of', 'department,', '(fire', 'department)']
# ['assistant', 'chief', 'of', 'department,', '(fire', 'department)']
# ['battalion', 'chief,', '(fire', 'department)']
# ['battalion', 'chief,', '(fire', 'department)']
# ['battalion', 'chief,', '(fire', 'department)']
# ['chief', 'of', 'police']
# ['battalion', 'chief,', '(fire', 'department)']
# ['deputy', 'chief', 'iii', '(police', 'department)']
# ['deputy', 'chief', 'of', 'department,(fire', 'department)']
# ['deputy', 'chief', 'iii', '(police', 'department)']
# ['battalion', 'chief,', '(fire', 'department)']
# ['battalion', 'chief,', '(fire', 'department)']
# ['battalion', 'chief,', '(fire', 'department)']
# ['battalion', 'chief,', '(fire', 'department)']
# ['deputy', 'chief', 'of', 'department,(fire', 'department)']
# ['battalion', 'chief,', '(fire', 'department)']
# ['deputy', 'chief', 'iii', '(police', 'department)']
# ['battalion', 'chief,', '(fire', 'department)']
# ['deputy', 'chief', 'iii', '(police', 'department)']
# ['assistant', 'deputy', 'chief', 'ii']
# ['battalion', 'chief,', '(fire', 'department)']
# ['assistant', 'chief', 'of', 'department,', '(fire', 'department)']
# ['deputy', 'chief', 'iii', '(police', 'department)']
# ['battalion', 'chief,', '(fire', 'department)']
# ['battalion', 'chief,', '(fire', 'department)']
# ['battalion', 'chief,', '(fire', 'department)']
# ['battalion', 'chief,', '(fire', 'department)']
# ['battalion', 'chief,', '(fire', 'department)']
# ['battalion', 'chief,', '(fire', 'department)']
# ['battalion', 'chief,', '(fire', 'department)']
# ['battalion', 'chief,', '(fire', 'department)']
# ['battalion', 'chief,', '(fire', 'department)']
# ['battalion', 'chief,', '(fire', 'department)']
# ['battalion', 'chief,', '(fire', 'department)']
# ['battalion', 'chief,', '(fire', 'department)']
# ['battalion', 'chief,', '(fire', 'department)']
# ['confidential', 'chief', 'attorney', 'ii', '(civil', '&', 'criminal)']
# ['confidential', 'chief', 'attorney', 'ii', '(civil', '&', 'criminal)']
# ['confidential', 'chief', 'attorney', 'ii', '(civil', '&', 'criminal)']
# ['battalion', 'chief,', '(fire', 'department)']
# ['battalion', 'chief,', '(fire', 'department)']
# ['battalion', 'chief,', '(fire', 'department)']
# ['chief', 'attorney', 'i', '(civil', '&', 'criminal)']
# ['battalion', 'chief,', '(fire', 'department)']
# ['battalion', 'chief,', '(fire', 'department)']
# ['assistant', 'deputy', 'chief', 'ii']
# ['assistant', 'deputy', 'chief', 'ii']
# ['chief', 'attorney', 'i', '(civil', '&', 'criminal)']
# ['chief', 'attorney', 'i', '(civil', '&', 'criminal)']
# ['battalion', 'chief,', '(fire', 'department)']
# ['battalion', 'chief,', '(fire', 'department)']
# ['assistant', 'chief', 'attorney', 'ii']
# ['assistant', 'chief', 'attorney', 'ii']
# ['assistant', 'chief', 'attorney', 'ii']
# ['chief', 'probation', 'officer,', 'juvenile', 'court']
# ['assistant', 'chief', 'attorney', 'ii']
# ['battalion', 'chief,', '(fire', 'department)']
# ['chief', 'adult', 'probation', 'officer']
# ['battalion', 'chief,', '(fire', 'department)']
# ['assistant', 'chief', 'attorney', 'i']
# ['assistant', 'chief', 'attorney', 'i']
# ['assistant', 'chief', 'attorney', 'i']
# ['assistant', 'chief', 'attorney', 'i']
# ['assistant', 'chief', 'attorney', 'i']
# ['assistant', 'chief', 'attorney', 'i']
# ['assistant', 'chief', 'attorney', 'i']
# ['assistant', 'chief', 'attorney', 'i']
# ['assistant', 'chief', 'attorney', 'i']
# ['assistant', 'chief', 'attorney', 'i']
# ['assistant', 'chief', 'attorney', 'i']
# ['assistant', 'chief', 'attorney', 'i']
# ['assistant', 'chief', 'attorney', 'i']
# ['assistant', 'chief', 'attorney', 'i']
# ['assistant', 'chief', 'attorney', 'i']
# ['assistant', 'chief', 'attorney', 'i']
# ['assistant', 'chief', 'attorney', 'i']
# ['assistant', 'chief', 'attorney', 'i']
# ['battalion', 'chief,', '(fire', 'department)']
# ['assistant', 'chief', 'attorney', 'i']
# ['assistant', 'chief', 'attorney', 'i']
# ['battalion', 'chief,', '(fire', 'department)']
# ['battalion', 'chief,', '(fire', 'department)']
# ['battalion', 'chief,', '(fire', 'department)']
# ['battalion', 'chief,', '(fire', 'department)']
# ['assistant', 'chief', 'attorney', 'i']
# ['assistant', 'deputy', 'chief', 'ii']
# ['battalion', 'chief,', '(fire', 'department)']
# ['chief', 'deputy', 'sheriff']
# ['asst.', 'chief', 'probation', 'officer-juvenile', 'probation']
# ['chief', 'deputy', 'sheriff']
# ['chief', 'deputy', 'sheriff']
# ['battalion', 'chief,', '(fire', 'department)']
# ['assistant', 'chief', 'attorney', 'ii']
# ['chief', 'district', "attorney's", 'investigator']
# ['chief', 'stationary', 'engineer']
# ['chief', 'water', 'service', 'inspector']
# ['battalion', 'chief,', '(fire', 'department)']
# ['chief', 'attorney', 'i', '(civil', '&', 'criminal)']
# ['chief', 'stationary', 'engineer']
# ['chief', 'stationary', 'engineer,', 'water', 'treatment', 'plant']
# ['chief', 'stationary', 'engineer']
# ['chief', 'stationary', 'engineer,', 'water', 'treatment', 'plant']
# ['asst.', 'chief,', 'bureau', 'of', 'claims', 'invest.', '&', 'admin']
# ['chief', 'stationary', 'engineer,', 'water', 'treatment', 'plant']
# ['chief', 'building', 'inspector']
# ['chief', 'building', 'inspector']
# ['chief', 'plumbing', 'inspector']
# ['chief', 'water', 'service', 'inspector']
# ['battalion', 'chief,', '(fire', 'department)']
# ['chief', 'stationary', 'engineer,', 'water', 'treatment', 'plant']
# ['chief', 'electrical', 'inspector']
# ['chief', 'stationary', 'engineer']
# ['chief', 'building', 'inspector']
# ['chief', 'stationary', 'engineer,', 'sewage', 'plant']
# ['chief', 'stationary', 'engineer,', 'water', 'treatment', 'plant']
# ['chief', 'stationary', 'engineer,', 'sewage', 'plant']
# ['chief', 'stationary', 'engineer,', 'sewage', 'plant']
# ['chief', 'stationary', 'engineer,', 'sewage', 'plant']
# ['chief', 'housing', 'inspector']
# ['assistant', 'chief', 'district', "attorney's", 'investigator']
# ['chief', 'stationary', 'engineer,', 'sewage', 'plant']
# ['assistant', 'chief', 'district', "attorney's", 'investigator']
# ['chief', 'stationary', 'engineer,', 'sewage', 'plant']
# ['assistant', 'chief', 'district', "attorney's", 'investigator']
# ['assistant', 'chief', 'district', "attorney's", 'investigator']
# ['chief', 'stationary', 'engineer,', 'sewage', 'plant']
# ['chief', 'water', 'service', 'inspector']
# ['chief', 'stationary', 'engineer']
# ['chief', 'microbiologist']
# ['chief', 'surveyor']
# ['chief', 'stationary', 'engineer,', 'sewage', 'plant']
# ['chief', 'stationary', 'engineer,', 'sewage', 'plant']
# ['chief', 'surveyor']
# ['chief', 'fire', 'alarm', 'dispatcher']
# ['chief', 'stationary', 'engineer,', 'sewage', 'plant']
# ['chief', 'stationary', 'engineer,', 'sewage', 'plant']
# ['chief', 'stationary', 'engineer,', 'sewage', 'plant']
# ['chief', 'stationary', 'engineer']
# ['chief', 'surveyor']
# ['chief', 'stationary', 'engineer,', 'sewage', 'plant']
# ['chief', 'stationary', 'engineer']
# ['chief', 'stationary', 'engineer,', 'sewage', 'plant']
# ['chief', 'stationary', 'engineer,', 'sewage', 'plant']
# ['chief', 'stationary', 'engineer,', 'sewage', 'plant']
# ['chief', 'stationary', 'engineer,', 'sewage', 'plant']
# ['chief', 'stationary', 'engineer,', 'sewage', 'plant']
# ['chief', 'stationary', 'engineer,', 'sewage', 'plant']
# ['chief', 'stationary', 'engineer,', 'sewage', 'plant']
# ['chief', 'stationary', 'engineer']
# ['chief', 'stationary', 'engineer']
# ['chief', 'stationary', 'engineer']
# ['chief', 'victim/witness', 'investigator']
# ['chief', 'stationary', 'engineer']
# ['chief', 'stationary', 'engineer']
# ['chief', 'stationary', 'engineer']
# ['chief', 'surveyor']
# ['assistant', 'chief', 'victim/witness', 'investigator']
# ['assistant', 'chief', 'victim/witness', 'investigator']
# ['assistant', 'chief', 'victim/witness', 'investigator']
# ['assistant', 'chief', 'victim/witness', 'investigator']
# ['chief', 'stationary', 'engineer']
# ['assistant', 'chief', 'victim/witness', 'investigator']
# ['chief', 'nursery', 'specialist']
# ['chief', 'dietitian']
# ['chief', 'dietitian']
# ['chief', 'payroll', 'and', 'personnel', 'clerk']
# ['chief', 'clerk']
# ['chief', 'payroll', 'and', 'personnel', 'clerk']
# ['chief', 'clerk']
# ['assistant', 'chief', 'of', 'department,', '(fire', 'department)']
# ['chief', 'clerk']
# ['chief', 'clerk']
# ['chief', 'clerk']
# ['chief', 'clerk']
# ['chief', 'clerk']
# ['chief', 'clerk']
# ['chief', 'clerk']
# ['chief', 'clerk']
# ['chief', 'deputy', 'adult', 'probation', 'officer']
# ['chief', 'payroll', 'and', 'personnel', 'clerk']
# ['chief', 'clerk']
# ['chief', 'stationary', 'engineer,', 'sewage', 'plant']
# ['chief', 'clerk']
# ['chief', 'clerk']
# ['assistant', 'chief', 'attorney', 'i']
# ['chief', 'clerk']
# ['chief', 'attorney', 'i', '(civil', '&', 'criminal)']
# ['assistant', 'chief', 'attorney', 'i']
# ['chief', 'surveyor']
# ['chief', 'telephone', 'operator']
# ['chief', 'deputy', 'adult', 'probation', 'officer']
# ['chief', 'preparator']
# ['chief', 'clerk']
# ['chief', 'stationary', 'engineer']
# ['chief', 'stationary', 'engineer,', 'sewage', 'plant']
# ['chief', 'preparator']
# ['battalion', 'chief,', '(fire', 'department)']
# ['chief', 'surveyor']
# ['chief', 'payroll', 'and', 'personnel', 'clerk']
# ['chief', 'adult', 'probation', 'officer']
# ['chief', 'of', 'police']
# ['chief,', 'fire', 'department']
# ['battlion', 'chief,', 'fire', 'suppressi']
# ['battlion', 'chief,', 'fire', 'suppressi']
# ['battlion', 'chief,', 'fire', 'suppressi']
# ['battlion', 'chief,', 'fire', 'suppressi']
# ['assistant', 'deputy', 'chief', '2']
# ['assistant', 'deputy', 'chief', '2']
# ['deputy', 'chief', '3']
# ['assistant', 'deputy', 'chief', '2']
# ['deputy', 'chief', '3']
# ['deputy', 'chief', '3']
# ['battlion', 'chief,', 'fire', 'suppressi']
# ['deputy', 'chief', '3']
# ['battlion', 'chief,', 'fire', 'suppressi']
# ['battlion', 'chief,', 'fire', 'suppressi']
# ['battlion', 'chief,', 'fire', 'suppressi']
# ['battlion', 'chief,', 'fire', 'suppressi']
# ['battlion', 'chief,', 'fire', 'suppressi']
# ['battlion', 'chief,', 'fire', 'suppressi']
# ['battlion', 'chief,', 'fire', 'suppressi']
# ['battlion', 'chief,', 'fire', 'suppressi']
# ['assistant', 'deputy', 'chief', '2']
# ['emergency', 'medical', 'svcs', 'chief']
# ['deputy', 'chief', '3']
# ['battlion', 'chief,', 'fire', 'suppressi']
# ['battlion', 'chief,', 'fire', 'suppressi']
# ['deputy', 'chief', '3']
# ['battlion', 'chief,', 'fire', 'suppressi']
# ['battlion', 'chief,', 'fire', 'suppressi']
# ['battlion', 'chief,', 'fire', 'suppressi']
# ['battlion', 'chief,', 'fire', 'suppressi']
# ['chief', 'atty1', '(civil', '&', 'criminal)']
# ['battlion', 'chief,', 'fire', 'suppressi']
# ['battlion', 'chief,', 'fire', 'suppressi']
# ['battlion', 'chief,', 'fire', 'suppressi']
# ['battlion', 'chief,', 'fire', 'suppressi']
# ['chief', 'atty1', '(civil', '&', 'criminal)']
# ['chief', 'adult', 'probation', 'officer']
# ['assistant', 'chief', 'attorney', '2']
# ['assistant', 'chief', 'attorney', '2']
# ['assistant', 'chief', 'attorney', '2']
# ['battlion', 'chief,', 'fire', 'suppressi']
# ['assistant', 'chief', 'attorney', '2']
# ['assistant', 'chief', 'attorney', '2']
# ['battlion', 'chief,', 'fire', 'suppressi']
# ['assistant', 'chief', 'attorney', '1']
# ['battlion', 'chief,', 'fire', 'suppressi']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '2']
# ['battlion', 'chief,', 'fire', 'suppressi']
# ['assistant', 'chief', 'attorney', '1']
# ['battlion', 'chief,', 'fire', 'suppressi']
# ['battlion', 'chief,', 'fire', 'suppressi']
# ['assistant', 'chief', 'attorney', '1']
# ['battlion', 'chief,', 'fire', 'suppressi']
# ['assistant', 'chief', 'attorney', '1']
# ['chief', 'atty1', '(civil', '&', 'criminal)']
# ['battlion', 'chief,', 'fire', 'suppressi']
# ['chief', 'atty1', '(civil', '&', 'criminal)']
# ['chief', 'atty1', '(civil', '&', 'criminal)']
# ['chief', 'deputy', 'sheriff']
# ['battlion', 'chief,', 'fire', 'suppressi']
# ['chief', 'deputy', 'sheriff']
# ['chief', 'stationary', 'engineer']
# ['assistant', 'chief', 'attorney', '1']
# ['chief', 'deputy', 'sheriff']
# ['chief', 'water', 'service', 'inspector']
# ['chief', 'stationary', 'engineer']
# ['assistant', 'deputy', 'chief', '2']
# ['chief', 'building', 'inspector']
# ['battlion', 'chief,', 'fire', 'suppressi']
# ['chief', 'plumbing', 'inspector']
# ['chief', 'building', 'inspector']
# ['chief', 'building', 'inspector']
# ['chief', 'stationary', 'engineer']
# ['chief', 'water', 'service', 'inspector']
# ['assistant', 'chief', 'attorney', '1']
# ['chief', 'electrical', 'inspector']
# ['chief', 'stationary', 'engineer']
# ['chief', 'housing', 'inspector']
# ['chief', 'dep', 'adlt', 'prob', 'of', '(sfers)']
# ['chief', 'fire', 'alarm', 'dispatcher']
# ['chief', 'surveyor']
# ['chief', 'stationary', 'engineer']
# ['chief', 'water', 'service', 'inspector']
# ['chief', 'surveyor']
# ['chief', 'surveyor']
# ['chief', 'stationary', 'engineer']
# ['chief', 'stationary', 'engineer']
# ['chief', 'stationary', 'engineer']
# ['chief', 'stationary', 'engineer']
# ['chief', 'surveyor']
# ['chief', 'stationary', 'engineer']
# ['chief', 'stationary', 'engineer']
# ['chief', 'stationary', 'engineer']
# ['battlion', 'chief,', 'fire', 'suppressi']
# ['chief', 'stationary', 'engineer']
# ['chief', 'nursery', 'specialist']
# ['chief', 'dietitian']
# ['chief', 'dietitian']
# ['chief', 'deputy', 'sheriff']
# ['chief', 'clerk']
# ['chief', 'clerk']
# ['chief', 'clerk']
# ['chief', 'clerk']
# ['chief', 'clerk']
# ['chief', 'clerk']
# ['chief', 'clerk']
# ['chief', 'clerk']
# ['chief', 'clerk']
# ['chief', 'clerk']
# ['chief', 'preparator']
# ['chief', 'clerk']
# ['chief', 'clerk']
# ['chief', 'telephone', 'operator']
# ['chief', 'clerk']
# ['chief', 'clerk']
# ['assistant', 'chief', 'attorney', '1']
# ['chief', 'deputy', 'adlt', 'probation', 'of']
# ['assistant', 'chief', 'attorney', '2']
# ['assistant', 'chief', 'attorney', '1']
# ['chief', 'clerk']
# ['chief', 'surveyor']
# ['battlion', 'chief,', 'fire', 'suppressi']
# ['chief', 'deputy', 'adlt', 'probation', 'of']
# ['chief', 'clerk']
# ['battlion', 'chief,', 'fire', 'suppressi']
# ['chief', 'of', 'police']
# ['chief,', 'fire', 'department']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['deputy', 'chief', '3']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['deputy', 'chief', '3']
# ['assistant', 'deputy', 'chief', '2']
# ['deputy', 'chief', '3']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['deputy', 'chief', '3']
# ['deputy', 'chief', '3']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['assistant', 'deputy', 'chief', '2']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['assistant', 'deputy', 'chief', '2']
# ['emergency', 'medical', 'svcs', 'chief']
# ['assistant', 'deputy', 'chief', '2']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['assistant', 'deputy', 'chief', '2']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['chief', 'atty1', '(civil', '&', 'criminal)']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['chief', 'atty1', '(civil', '&', 'criminal)']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['chief', 'atty1', '(civil', '&', 'criminal)']
# ['assistant', 'chief', 'attorney', '2']
# ['chief', 'adult', 'probation', 'officer']
# ['assistant', 'chief', 'attorney', '2']
# ['assistant', 'chief', 'attorney', '2']
# ['assistant', 'chief', 'attorney', '2']
# ['assistant', 'chief', 'attorney', '2']
# ['assistant', 'chief', 'attorney', '2']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['chief', 'atty1', '(civil', '&', 'criminal)']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['chief', 'deputy', 'sheriff']
# ['chief', 'deputy', 'sheriff']
# ['chief', 'deputy', 'sheriff']
# ['chief', 'dep', 'adlt', 'prob', 'of', '(sfers)']
# ['chief', 'stationary', 'engineer']
# ['deputy', 'chief', '3']
# ['chief', 'water', 'service', 'inspector']
# ['chief', 'stationary', 'engineer']
# ['chief', 'plumbing', 'inspector']
# ['chief', 'building', 'inspector']
# ['chief', 'building', 'inspector']
# ['chief', 'building', 'inspector']
# ['chief', 'water', 'service', 'inspector']
# ['chief', 'electrical', 'inspector']
# ['chief', 'building', 'inspector']
# ['chief', 'stationary', 'engineer']
# ['chief', 'water', 'service', 'inspector']
# ['chief', 'housing', 'inspector']
# ['chief', 'fire', 'alarm', 'dispatcher']
# ['chief', 'stationary', 'engineer']
# ['chief', 'surveyor']
# ['chief', 'surveyor']
# ['chief', 'surveyor']
# ['chief', 'stationary', 'engineer']
# ['chief', 'stationary', 'engineer']
# ['chief', 'stationary', 'engineer']
# ['chief', 'surveyor']
# ['deputy', 'chief', '3']
# ['chief', 'stationary', 'engineer']
# ['chief', 'stationary', 'engineer']
# ['chief', 'stationary', 'engineer']
# ['chief', 'dietitian']
# ['chief', 'nursery', 'specialist']
# ['chief', 'building', 'inspector']
# ['chief', 'stationary', 'engineer']
# ['chief', 'dietitian']
# ['chief', 'clerk']
# ['chief', 'clerk']
# ['chief', 'clerk']
# ['chief', 'clerk']
# ['chief', 'clerk']
# ['chief', 'clerk']
# ['chief', 'clerk']
# ['chief', 'clerk']
# ['chief', 'clerk']
# ['chief', 'clerk']
# ['chief', 'clerk']
# ['chief', 'clerk']
# ['chief', 'preparator']
# ['chief', 'clerk']
# ['chief', 'telephone', 'operator']
# ['chief', 'stationary', 'engineer']
# ['chief', 'stationary', 'engineer']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['chief', 'deputy', 'adlt', 'probation', 'of']
# ['chief', 'stationary', 'engineer']
# ['assistant', 'chief', 'attorney', '1']
# ['chief', 'surveyor']
# ['chief', 'clerk']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['chief', 'preparator']
# ['chief', 'clerk']
# ['chief', 'clerk']
# ['deputy', 'chief', '3']
# ['chief', 'investment', 'officer']
# ['chief', 'of', 'police']
# ['chief,', 'fire', 'department']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['deputy', 'chief', '3']
# ['deputy', 'chief', '3']
# ['deputy', 'chief', '3']
# ['deputy', 'chief', '3']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['deputy', 'chief', '3']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['assistant', 'deputy', 'chief', '2']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['emergency', 'medical', 'svcs', 'chief']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['chief', 'atty1', '(civil', '&', 'criminal)']
# ['chief', 'forensic', 'toxicologist']
# ['chief', 'atty1', '(civil', '&', 'criminal)']
# ['chief', 'atty1', '(civil', '&', 'criminal)']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['chief', 'atty1', '(civil', '&', 'criminal)']
# ['chief', 'adult', 'probation', 'officer']
# ['assistant', 'chief', 'attorney', '2']
# ['assistant', 'chief', 'attorney', '2']
# ['assistant', 'chief', 'attorney', '2']
# ['assistant', 'chief', 'attorney', '2']
# ['assistant', 'chief', 'attorney', '2']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['battalion', 'chief,', 'fire', 'suppress']
# ['deputy', 'chief', '3']
# ['assistant', 'chief', 'attorney', '1']
# ['assistant', 'chief', 'attorney', '1']
# ['chief', 'deputy', 'sheriff']
# ['chief', 'deputy', 'sheriff']
# ['chief', 'deputy', 'sheriff']
# ['chief', 'dep', 'adlt', 'prob', 'of', '(sfers)']
# ['deputy', 'chief', '3']
# ['chief', 'water', 'service', 'inspector']
# ['chief', 'stationary', 'engineer']
# ['chief', 'building', 'inspector']
# ['chief', 'water', 'service', 'inspector']
# ['chief', 'building', 'inspector']
# ['chief', 'plumbing', 'inspector']
# ['chief', 'building', 'inspector']
# ['chief', 'building', 'inspector']
# ['chief', 'electrical', 'inspector']
# ['chief', 'stationary', 'engineer']
# ['chief', 'stationary', 'engineer']
# ['chief', 'stationary', 'engineer']
# ['chief', 'stationary', 'engineer']
# ['chief', 'water', 'service', 'inspector']
# ['chief', 'surveyor']
# ['chief', 'surveyor']
# ['chief', 'surveyor']
# ['chief', 'surveyor']
# ['chief', 'stationary', 'engineer']
# ['chief', 'surveyor']
# ['chief', 'surveyor']
# ['chief', 'stationary', 'engineer']
# ['chief', 'stationary', 'engineer']
# ['chief', 'stationary', 'engineer']
# ['chief', 'atty1', '(civil', '&', 'criminal)']
# ['chief', 'stationary', 'engineer']
# ['chief', 'stationary', 'engineer']
# ['chief', 'housing', 'inspector']
# ['chief', 'stationary', 'engineer']
# ['chief', 'stationary', 'engineer']
# ['chief', 'stationary', 'engineer']
# ['chief', 'fire', 'alarm', 'dispatcher']
# ['chief', 'surveyor']
# ['chief', 'dietitian']
# ['chief', 'stationary', 'engineer']
# ['chief', 'surveyor']
# ['chief', 'clerk']
# ['chief', 'clerk']
# ['chief', 'clerk']
# ['chief', 'clerk']
# ['chief', 'clerk']
# ['chief', 'clerk']
# ['chief', 'clerk']
# ['chief', 'clerk']
# ['assistant', 'chief', 'attorney', '1']
# ['chief', 'clerk']
# ['chief', 'clerk']
# ['chief', 'clerk']
# ['chief', 'telephone', 'operator']
# ['assistant', 'chief', 'attorney', '1']
# ['chief', 'clerk']
# ['chief', 'preparator']
# ['chief', 'surveyor']
# ['assistant', 'chief', 'attorney', '1']
# ['chief', 'deputy', 'adlt', 'probation', 'of']
# ['chief', 'clerk']
# ['chief', 'nursery', 'specialist']
# ['chief', 'preparator']
# ['chief', 'stationary', 'engineer']
# 627

# %%
# Out:
# 477

# %% [markdown]
# ** Bonus: Is there a correlation between length of the Job Title string and Salary? **

# %%
data['totallen'] = data['JobTitle'].apply(len)
data[['totallen','TotalPayBenefits']].corr()
# Out:
#                   totallen  TotalPayBenefits
# totallen          1.000000         -0.036878
# TotalPayBenefits -0.036878          1.000000

# %% [markdown]
# # Great Job!
