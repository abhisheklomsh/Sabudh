# %%
"""Author: Abhishek Lomsh
Here I have tried to build a crawler which collects baby names from given website"""
# Out:
# 'Author: Abhishek Lomsh\nHere I have tried to build a crawler which collects baby names from given website'

# %%
import requests
from bs4 import BeautifulSoup
import json

# %%
def spider(year):
    id = 0
    movie_details = {}
    page = 1
    max_pages = 200
    while page <= max_pages:
        print((page,year))
        url = 'https://www.imdb.com/search/title?release_date='+str(year)
        source_code = requests.get(url, allow_redirects=False)
        
        soup = BeautifulSoup(source_code.text,'html.parser')
        movies = soup.find_all('div', class_ = 'lister-item mode-advanced')
        for movie in movies:
            name = movie.h3.a.text
            print(name)
            descrption = movie.find_all('p',class_ = 'text-muted')[1].text
            movie_details[id]= {'name':name,'year':year,'plot':descrption}
            
            id+=1
        page+=1
    with open(str(year)+'.json','w') as fp:
        json.dump(movie_details,fp,indent=4)
        print('Done')

for year in range(1915,2018):
    spider(year)
# Out:
# (1, 1915)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/abhisheklomsh/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             try:  # Python 2.7, use buffering of HTTP responses
# --> 379                 httplib_response = conn.getresponse(buffering=True)
#     380             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-bf55aabc1099> in <module>()
#      24
#      25 for year in range(1915,2018):
# ---> 26     spider(year)
#
# <ipython-input-3-bf55aabc1099> in spider(year)
#       7         print((page,year))
#       8         url = 'https://www.imdb.com/search/title?release_date='+str(year)
# ----> 9         source_code = requests.get(url, allow_redirects=False)
#      10
#      11         soup = BeautifulSoup(source_code.text,'html.parser')
#
# /Users/abhisheklomsh/anaconda/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      68
#      69     kwargs.setdefault('allow_redirects', True)
# ---> 70     return request('get', url, params=params, **kwargs)
#      71
#      72
#
# /Users/abhisheklomsh/anaconda/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      54     # cases, and look like a memory leak in others.
#      55     with sessions.Session() as session:
# ---> 56         return session.request(method=method, url=url, **kwargs)
#      57
#      58
#
# /Users/abhisheklomsh/anaconda/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     486         }
#     487         send_kwargs.update(settings)
# --> 488         resp = self.send(prep, **send_kwargs)
#     489
#     490         return resp
#
# /Users/abhisheklomsh/anaconda/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     607
#     608         # Send the request
# --> 609         r = adapter.send(request, **kwargs)
#     610
#     611         # Total elapsed time of the request (approximately)
#
# /Users/abhisheklomsh/anaconda/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     421                     decode_content=False,
#     422                     retries=self.max_retries,
# --> 423                     timeout=timeout
#     424                 )
#     425
#
# /Users/abhisheklomsh/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /Users/abhisheklomsh/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380             except TypeError:  # Python 2.6 and older, Python 3
#     381                 try:
# --> 382                     httplib_response = conn.getresponse()
#     383                 except Exception as e:
#     384                     # Remove the TypeError from the exception chain in Python 3;
#
# /Users/abhisheklomsh/anaconda/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# /Users/abhisheklomsh/anaconda/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /Users/abhisheklomsh/anaconda/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /Users/abhisheklomsh/anaconda/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /Users/abhisheklomsh/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     275     def recv_into(self, *args, **kwargs):
#     276         try:
# --> 277             return self.connection.recv_into(*args, **kwargs)
#     278         except OpenSSL.SSL.SysCallError as e:
#     279             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# /Users/abhisheklomsh/anaconda/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1544             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1545         else:
# -> 1546             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1547         self._raise_ssl_error(self._ssl, result)
#    1548
#
# KeyboardInterrupt:

# %%
def crawler(year):
    id = 0
    name_details = {}
    page = 1
    max_pages = 200
    while page <= max_pages:
        print((page,year))
        url = 'https://nameberry.com/search?page='+str(page)+'&per_page=30&starts_with='+(chr(char))
        print(url)
        source_code = requests.get(url, allow_redirects=False)
        
        soup = BeautifulSoup(source_code.text,'html.parser')
        
        
        
        
        for div in soup.find_all('h4'):
            try:
            
                name = div.find('a').contents[0]
                gender = div.find('a')['class'][1]
                name_details[id]= {'name':name,'gender':gender}
                print(name_details[id])
                id+=1
            except:
                continue
                
                
            
                
            
            #print(name)
            #descrption = movie.find_all('p',class_ = 'text-muted')[1].text
            #movie_details[id]= {'name':name,'year':year,'plot':descrption}
            
        page+=1
        
    with open(str(char)+'.txt','w') as fp:
        fp.write(str(name_details))
        print('Done')

for char in range(65,92):
    crawler(char)
# Out:
# (1, 65)
# https://nameberry.com/search?page=1&per_page=30&starts_with=A
# {'name': 'Aabbee', 'gender': 'girl'}
# {'name': 'Aabriella', 'gender': 'girl'}
# {'name': 'Aada', 'gender': 'girl'}
# {'name': 'Aadam', 'gender': 'boy'}
# {'name': 'Aaden', 'gender': 'boy'}
# {'name': 'Aadhya', 'gender': 'girl'}
# {'name': 'Aadya', 'gender': 'girl'}
# {'name': 'Aafke', 'gender': 'girl'}
# {'name': 'Aage', 'gender': 'boy'}
# {'name': 'Aahil', 'gender': 'boy'}
# {'name': 'Aahliyah', 'gender': 'girl'}
# {'name': 'Aahron', 'gender': 'boy'}
# {'name': 'Aailiyah', 'gender': 'girl'}
# {'name': 'Aailyah', 'gender': 'girl'}
# {'name': 'Aairah', 'gender': 'girl'}
# {'name': 'Aaisha', 'gender': 'girl'}
# {'name': 'Aaishah', 'gender': 'girl'}
# {'name': 'Aakil', 'gender': 'boy'}
# {'name': 'Aalaiya', 'gender': 'girl'}
# {'name': 'Aaleah', 'gender': 'girl'}
# {'name': 'Aaleasha', 'gender': 'girl'}
# {'name': 'Aalexis', 'gender': 'girl'}
# {'name': 'Aaleyah', 'gender': 'girl'}
# {'name': 'Aalia', 'gender': 'girl'}
# {'name': 'Aaliesha', 'gender': 'girl'}
# {'name': 'Aalieyha', 'gender': 'girl'}
# {'name': 'Aalisha', 'gender': 'girl'}
# {'name': 'Aaliya', 'gender': 'girl'}
# {'name': 'Aaliyah', 'gender': 'girl'}
# {'name': 'Aaliyaha', 'gender': 'girl'}
# (2, 65)
# https://nameberry.com/search?page=2&per_page=30&starts_with=A
# {'name': 'Aaliyha', 'gender': 'girl'}
# {'name': 'Aalliah', 'gender': 'girl'}
# {'name': 'Aallyah', 'gender': 'girl'}
# {'name': 'Aalto', 'gender': 'boy'}
# {'name': 'Aalyah', 'gender': 'girl'}
# {'name': 'Aalyiah', 'gender': 'girl'}
# {'name': 'Aamani', 'gender': 'girl'}
# {'name': 'Aamber', 'gender': 'girl'}
# {'name': 'Aamena', 'gender': 'girl'}
# {'name': 'Aami', 'gender': 'girl'}
# {'name': 'Aamina', 'gender': 'girl'}
# {'name': 'Aaminah', 'gender': 'girl'}
# {'name': 'Aamu', 'gender': 'girl'}
# {'name': 'Aang', 'gender': 'boy'}
# {'name': 'Aanisa', 'gender': 'girl'}
# {'name': 'Aanisah', 'gender': 'girl'}
# {'name': 'Aaniyah', 'gender': 'girl'}
# {'name': 'Aany', 'gender': 'girl'}
# {'name': 'Aanya', 'gender': 'girl'}
# {'name': 'Aanye', 'gender': 'girl'}
# {'name': 'Aaran', 'gender': 'boy'}
# {'name': 'Aarav', 'gender': 'boy'}
# {'name': 'Aaren', 'gender': 'boy'}
# {'name': 'Aaric', 'gender': 'boy'}
# {'name': 'Aariz', 'gender': 'boy'}
# {'name': 'Aarna', 'gender': 'girl'}
# {'name': 'Aaron', 'gender': 'boy'}
# {'name': 'Aarron', 'gender': 'boy'}
# {'name': 'Aart', 'gender': 'boy'}
# (3, 65)
# https://nameberry.com/search?page=3&per_page=30&starts_with=A
# {'name': 'Aaru', 'gender': 'boy'}
# {'name': 'Aarush', 'gender': 'boy'}
# {'name': 'Aarya', 'gender': 'girl'}
# {'name': 'Aaryan', 'gender': 'boy'}
# {'name': 'Aasiyah', 'gender': 'girl'}
# {'name': 'Aatami', 'gender': 'boy'}
# {'name': 'Aatu', 'gender': 'boy'}
# {'name': 'Aayan', 'gender': 'boy'}
# {'name': 'Aayat', 'gender': 'girl'}
# {'name': 'Aayden', 'gender': 'boy'}
# {'name': 'Ab', 'gender': 'boy'}
# {'name': 'Aba', 'gender': 'boy'}
# {'name': 'Abaan', 'gender': 'boy'}
# {'name': 'Abacas', 'gender': 'boy'}
# {'name': 'Abacus', 'gender': 'boy'}
# {'name': 'Abad', 'gender': 'unisex'}
# {'name': 'Abad', 'gender': 'unisex'}
# {'name': 'Abaddon', 'gender': 'boy'}
# {'name': 'Abagael', 'gender': 'girl'}
# {'name': 'Abagail', 'gender': 'girl'}
# {'name': 'Abagale', 'gender': 'girl'}
# {'name': 'Abagil', 'gender': 'girl'}
# {'name': 'Abaigeal', 'gender': 'girl'}
# {'name': 'Abakus', 'gender': 'boy'}
# {'name': 'Abalard', 'gender': 'boy'}
# {'name': 'Abalene', 'gender': 'unisex'}
# {'name': 'Abalene', 'gender': 'unisex'}
# {'name': 'Abalina', 'gender': 'girl'}
# {'name': 'Abame', 'gender': 'girl'}
# (4, 65)
# https://nameberry.com/search?page=4&per_page=30&starts_with=A
# {'name': 'Aban', 'gender': 'boy'}
# {'name': 'Abanito', 'gender': 'boy'}
# {'name': 'Abanu', 'gender': 'boy'}
# {'name': 'Abarran', 'gender': 'boy'}
# {'name': 'Abarrane', 'gender': 'girl'}
# {'name': 'Abb', 'gender': 'boy'}
# {'name': 'Abba', 'gender': 'boy'}
# {'name': 'Abbagail', 'gender': 'girl'}
# {'name': 'Abbah', 'gender': 'boy'}
# {'name': 'Abban', 'gender': 'boy'}
# {'name': 'Abbas', 'gender': 'boy'}
# {'name': 'Abbe', 'gender': 'girl'}
# {'name': 'Abbea', 'gender': 'girl'}
# {'name': 'Abbee', 'gender': 'girl'}
# {'name': 'Abbeigh', 'gender': 'girl'}
# {'name': 'Abbeline', 'gender': 'girl'}
# {'name': 'Abbetina', 'gender': 'girl'}
# {'name': 'Abbey', 'gender': 'unisex'}
# {'name': 'Abbey', 'gender': 'unisex'}
# {'name': 'Abbi', 'gender': 'girl'}
# {'name': 'Abbia', 'gender': 'girl'}
# {'name': 'Abbiah', 'gender': 'girl'}
# {'name': 'Abbie', 'gender': 'unisex'}
# {'name': 'Abbie', 'gender': 'unisex'}
# {'name': 'Abbiegail', 'gender': 'girl'}
# {'name': 'Abbiegayle', 'gender': 'girl'}
# {'name': 'Abbigael', 'gender': 'girl'}
# {'name': 'Abbigail', 'gender': 'girl'}
# {'name': 'Abbigal', 'gender': 'girl'}
# {'name': 'Abbigale', 'gender': 'girl'}
# (5, 65)
# https://nameberry.com/search?page=5&per_page=30&starts_with=A
# {'name': 'Abbigayl', 'gender': 'girl'}
# {'name': 'Abbigayle', 'gender': 'girl'}
# {'name': 'Abboid', 'gender': 'unisex'}
# {'name': 'Abboid', 'gender': 'unisex'}
# {'name': 'Abbot', 'gender': 'unisex'}
# {'name': 'Abbot', 'gender': 'unisex'}
# {'name': 'Abbott', 'gender': 'unisex'}
# {'name': 'Abbott', 'gender': 'unisex'}
# {'name': 'Abbrienna', 'gender': 'girl'}
# {'name': 'Abbryana', 'gender': 'girl'}
# {'name': 'Abby', 'gender': 'unisex'}
# {'name': 'Abby', 'gender': 'unisex'}
# {'name': 'Abbye', 'gender': 'girl'}
# {'name': 'Abbygael', 'gender': 'girl'}
# {'name': 'Abbygail', 'gender': 'girl'}
# {'name': 'Abbygale', 'gender': 'girl'}
# {'name': 'Abdal', 'gender': 'boy'}
# {'name': 'Abdall', 'gender': 'boy'}
# {'name': 'Abdalla', 'gender': 'boy'}
# {'name': 'Abdallah', 'gender': 'boy'}
# {'name': 'Abdeel', 'gender': 'boy'}
# {'name': 'Abdel', 'gender': 'boy'}
# {'name': 'Abdiel', 'gender': 'boy'}
# {'name': 'Abdirahman', 'gender': 'boy'}
# {'name': 'Abdoul', 'gender': 'boy'}
# {'name': 'Abdu', 'gender': 'boy'}
# {'name': 'Abdul', 'gender': 'boy'}
# {'name': 'Abdulah', 'gender': 'boy'}
# {'name': 'Abdulaziz', 'gender': 'boy'}
# (6, 65)
# https://nameberry.com/search?page=6&per_page=30&starts_with=A
# {'name': 'Abdull', 'gender': 'boy'}
# {'name': 'Abdulla', 'gender': 'boy'}
# {'name': 'Abdullah', 'gender': 'boy'}
# {'name': 'Abdullahi', 'gender': 'boy'}
# {'name': 'Abdulrahman', 'gender': 'boy'}
# {'name': 'Abdur', 'gender': 'boy'}
# {'name': 'Abdur', 'gender': 'boy'}
# {'name': 'Abdurrahman', 'gender': 'boy'}
# {'name': 'Abdylla', 'gender': 'boy'}
# {'name': 'Abe', 'gender': 'boy'}
# {'name': 'Abeba', 'gender': 'girl'}
# {'name': 'Abebe', 'gender': 'boy'}
# {'name': 'Abee', 'gender': 'girl'}
# {'name': 'Abeedja', 'gender': 'girl'}
# {'name': 'Abeeja', 'gender': 'girl'}
# {'name': 'Abeeku', 'gender': 'boy'}
# {'name': 'Abeer', 'gender': 'boy'}
# {'name': 'Abeesha', 'gender': 'girl'}
# {'name': 'Abeetal', 'gender': 'girl'}
# {'name': 'Abeey', 'gender': 'girl'}
# {'name': 'Abegail', 'gender': 'girl'}
# {'name': 'Abegale', 'gender': 'girl'}
# {'name': 'Abel', 'gender': 'boy'}
# {'name': 'Abelard', 'gender': 'boy'}
# {'name': 'Abelardo', 'gender': 'boy'}
# {'name': 'Abelhard', 'gender': 'boy'}
# {'name': 'Abelia', 'gender': 'girl'}
# {'name': 'Abell', 'gender': 'boy'}
# {'name': 'Abella', 'gender': 'girl'}
# {'name': 'Abelle', 'gender': 'girl'}
# (7, 65)
# https://nameberry.com/search?page=7&per_page=30&starts_with=A
# {'name': 'Abelone', 'gender': 'girl'}
# {'name': 'Abena', 'gender': 'girl'}
# {'name': 'Abenaa', 'gender': 'girl'}
# {'name': 'Aberdeen', 'gender': 'unisex'}
# {'name': 'Aberdeen', 'gender': 'unisex'}
# {'name': 'Abey', 'gender': 'unisex'}
# {'name': 'Abey', 'gender': 'unisex'}
# {'name': 'Abgail', 'gender': 'girl'}
# {'name': 'Abgale', 'gender': 'girl'}
# {'name': 'Abgayle', 'gender': 'girl'}
# {'name': 'Abi', 'gender': 'unisex'}
# {'name': 'Abi', 'gender': 'unisex'}
# {'name': 'Abia', 'gender': 'unisex'}
# {'name': 'Abia', 'gender': 'unisex'}
# {'name': 'Abiah', 'gender': 'unisex'}
# {'name': 'Abiah', 'gender': 'unisex'}
# {'name': 'Abichayil', 'gender': 'girl'}
# {'name': 'Abidan', 'gender': 'boy'}
# {'name': 'Abie', 'gender': 'unisex'}
# {'name': 'Abie', 'gender': 'unisex'}
# {'name': 'Abiel', 'gender': 'boy'}
# {'name': 'Abiela', 'gender': 'girl'}
# {'name': 'Abielah', 'gender': 'girl'}
# {'name': 'Abiell', 'gender': 'boy'}
# {'name': 'Abigael', 'gender': 'girl'}
# {'name': 'Abigail', 'gender': 'girl'}
# {'name': 'Abigaile', 'gender': 'girl'}
# {'name': 'Abigaill', 'gender': 'girl'}
# {'name': 'Abigal', 'gender': 'girl'}
# (8, 65)
# https://nameberry.com/search?page=8&per_page=30&starts_with=A
# {'name': 'Abigale', 'gender': 'girl'}
# {'name': 'Abigayil', 'gender': 'girl'}
# {'name': 'Abigayl', 'gender': 'girl'}
# {'name': 'Abigayle', 'gender': 'girl'}
# {'name': 'Abigel', 'gender': 'girl'}
# {'name': 'Abigial', 'gender': 'girl'}
# {'name': 'Abigil', 'gender': 'girl'}
# {'name': 'Abihail', 'gender': 'girl'}
# {'name': 'Abija', 'gender': 'girl'}
# {'name': 'Abijah', 'gender': 'unisex'}
# {'name': 'Abijah', 'gender': 'unisex'}
# {'name': 'Abilard', 'gender': 'boy'}
# {'name': 'Abileen', 'gender': 'boy'}
# {'name': 'Abilena', 'gender': 'girl'}
# {'name': 'Abilene', 'gender': 'unisex'}
# {'name': 'Abilene', 'gender': 'unisex'}
# {'name': 'Abilgail', 'gender': 'girl'}
# {'name': 'Abiline', 'gender': 'girl'}
# {'name': 'Abimael', 'gender': 'boy'}
# {'name': 'Abir', 'gender': 'boy'}
# {'name': 'Abiri', 'gender': 'boy'}
# {'name': 'Abisha', 'gender': 'unisex'}
# {'name': 'Abisha', 'gender': 'unisex'}
# {'name': 'Abishah', 'gender': 'girl'}
# {'name': 'Abital', 'gender': 'girl'}
# {'name': 'Abitha', 'gender': 'girl'}
# {'name': 'Able', 'gender': 'boy'}
# {'name': 'Abnar', 'gender': 'boy'}
# {'name': 'Abner', 'gender': 'boy'}
# {'name': 'Abnor', 'gender': 'boy'}
# (9, 65)
# https://nameberry.com/search?page=9&per_page=30&starts_with=A
# {'name': 'Abonee', 'gender': 'girl'}
# {'name': 'Abony', 'gender': 'girl'}
# {'name': 'Abot', 'gender': 'boy'}
# {'name': 'Abott', 'gender': 'boy'}
# {'name': 'Abra', 'gender': 'girl'}
# {'name': 'Abracham', 'gender': 'boy'}
# {'name': 'Abraham', 'gender': 'boy'}
# {'name': 'Abrahamo', 'gender': 'boy'}
# {'name': 'Abrahana', 'gender': 'girl'}
# {'name': 'Abrahn', 'gender': 'boy'}
# {'name': 'Abrail', 'gender': 'girl'}
# {'name': 'Abram', 'gender': 'boy'}
# {'name': 'Abramo', 'gender': 'boy'}
# {'name': 'Abrasha', 'gender': 'boy'}
# {'name': 'Abraxas', 'gender': 'boy'}
# {'name': 'Abrea', 'gender': 'girl'}
# {'name': 'Abreal', 'gender': 'girl'}
# {'name': 'Abreale', 'gender': 'girl'}
# {'name': 'Abreana', 'gender': 'girl'}
# {'name': 'Abreanna', 'gender': 'girl'}
# {'name': 'Abreanne', 'gender': 'girl'}
# {'name': 'Abree', 'gender': 'girl'}
# {'name': 'Abreeana', 'gender': 'girl'}
# {'name': 'Abreia', 'gender': 'girl'}
# {'name': 'Abreona', 'gender': 'girl'}
# {'name': 'Abreonia', 'gender': 'girl'}
# {'name': 'Abri', 'gender': 'girl'}
# {'name': 'Abria', 'gender': 'girl'}
# (10, 65)
# https://nameberry.com/search?page=10&per_page=30&starts_with=A
# {'name': 'Abriah', 'gender': 'girl'}
# {'name': 'Abrial', 'gender': 'girl'}
# {'name': 'Abriale', 'gender': 'girl'}
# {'name': 'Abriana', 'gender': 'girl'}
# {'name': 'Abriann', 'gender': 'girl'}
# {'name': 'Abrianna', 'gender': 'girl'}
# {'name': 'Abriannah', 'gender': 'girl'}
# {'name': 'Abrianne', 'gender': 'girl'}
# {'name': 'Abrieana', 'gender': 'girl'}
# {'name': 'Abriel', 'gender': 'girl'}
# {'name': 'Abriell', 'gender': 'girl'}
# {'name': 'Abrielle', 'gender': 'girl'}
# {'name': 'Abrien', 'gender': 'girl'}
# {'name': 'Abrienna', 'gender': 'girl'}
# {'name': 'Abrienne', 'gender': 'girl'}
# {'name': 'Abrietta', 'gender': 'girl'}
# {'name': 'Abril', 'gender': 'unisex'}
# {'name': 'Abril', 'gender': 'unisex'}
# {'name': 'Abrilla', 'gender': 'girl'}
# {'name': 'Abrille', 'gender': 'girl'}
# {'name': 'Abrion', 'gender': 'girl'}
# {'name': 'Abrionne', 'gender': 'girl'}
# {'name': 'Abriunna', 'gender': 'girl'}
# {'name': 'Abrya', 'gender': 'girl'}
# {'name': 'Abryann', 'gender': 'girl'}
# {'name': 'Abryanna', 'gender': 'girl'}
# {'name': 'Abryell', 'gender': 'girl'}
# {'name': 'Abryona', 'gender': 'girl'}
# (11, 65)
# https://nameberry.com/search?page=11&per_page=30&starts_with=A
# {'name': 'Absalom', 'gender': 'boy'}
# {'name': 'Absalon', 'gender': 'boy'}
# {'name': 'Abt', 'gender': 'unisex'}
# {'name': 'Abt', 'gender': 'unisex'}
# {'name': 'Abu', 'gender': 'boy'}
# {'name': 'Abubakar', 'gender': 'boy'}
# {'name': 'Abubakr', 'gender': 'boy'}
# {'name': 'Abugail', 'gender': 'girl'}
# {'name': 'Abush', 'gender': 'boy'}
# {'name': 'Aby', 'gender': 'girl'}
# {'name': 'Abya', 'gender': 'girl'}
# {'name': 'Abyah', 'gender': 'girl'}
# {'name': 'Abygail', 'gender': 'girl'}
# {'name': 'Abyssinia', 'gender': 'girl'}
# {'name': 'Acacia', 'gender': 'girl'}
# {'name': 'Acacius', 'gender': 'boy'}
# {'name': 'Acadia', 'gender': 'girl'}
# {'name': 'Acadiah', 'gender': 'girl'}
# {'name': 'Acadya', 'gender': 'girl'}
# {'name': 'Acadyah', 'gender': 'girl'}
# {'name': 'Acantha', 'gender': 'girl'}
# {'name': 'Acasha', 'gender': 'girl'}
# {'name': 'Acasia', 'gender': 'girl'}
# (12, 65)
# https://nameberry.com/search?page=12&per_page=30&starts_with=A
# {'name': 'Acasiya', 'gender': 'girl'}
# {'name': 'Acasya', 'gender': 'girl'}
# {'name': 'Acatia', 'gender': 'girl'}
# {'name': 'Acaysha', 'gender': 'girl'}
# {'name': 'Accacia', 'gender': 'girl'}
# {'name': 'Accalia', 'gender': 'girl'}
# {'name': 'Accasie', 'gender': 'girl'}
# {'name': 'Accassia', 'gender': 'girl'}
# {'name': 'Accerly', 'gender': 'boy'}
# {'name': 'Ace', 'gender': 'boy'}
# {'name': 'Acer', 'gender': 'boy'}
# {'name': 'Acey', 'gender': 'unisex'}
# {'name': 'Acey', 'gender': 'unisex'}
# {'name': 'Achante', 'gender': 'girl'}
# {'name': 'Achanti', 'gender': 'girl'}
# {'name': 'Achilios', 'gender': 'boy'}
# {'name': 'Achill', 'gender': 'boy'}
# {'name': 'Achille', 'gender': 'boy'}
# {'name': 'Achilleo', 'gender': 'boy'}
# {'name': 'Achilles', 'gender': 'boy'}
# {'name': 'Achilleus', 'gender': 'boy'}
# {'name': 'Achmad', 'gender': 'boy'}
# {'name': 'Achmed', 'gender': 'boy'}
# {'name': 'Achmet', 'gender': 'boy'}
# {'name': 'Achsah', 'gender': 'girl'}
# {'name': 'Acie', 'gender': 'unisex'}
# {'name': 'Acie', 'gender': 'unisex'}
# {'name': 'Acker', 'gender': 'boy'}
# {'name': 'Ackerley', 'gender': 'boy'}
# {'name': 'Ackerly,Ackley', 'gender': 'boy'}
# (13, 65)
# https://nameberry.com/search?page=13&per_page=30&starts_with=A
# {'name': 'Acklea', 'gender': 'boy'}
# {'name': 'Acklee', 'gender': 'boy'}
# {'name': 'Ackleigh', 'gender': 'boy'}
# {'name': 'Acquila', 'gender': 'boy'}
# {'name': 'Acquilla', 'gender': 'boy'}
# {'name': 'Acre', 'gender': 'boy'}
# {'name': 'Actaeon', 'gender': 'boy'}
# {'name': 'Actaviano', 'gender': 'boy'}
# {'name': 'Actavio', 'gender': 'boy'}
# {'name': 'Acteon', 'gender': 'boy'}
# {'name': 'Acton', 'gender': 'boy'}
# {'name': 'Acy', 'gender': 'boy'}
# {'name': 'Ad', 'gender': 'boy'}
# {'name': 'Ada', 'gender': 'girl'}
# {'name': 'Adabella', 'gender': 'girl'}
# {'name': 'Adabelle', 'gender': 'girl'}
# {'name': 'Adagio', 'gender': 'unisex'}
# {'name': 'Adagio', 'gender': 'unisex'}
# {'name': 'Adah', 'gender': 'girl'}
# {'name': 'Adaiah', 'gender': 'boy'}
# {'name': 'Adair', 'gender': 'unisex'}
# {'name': 'Adair', 'gender': 'unisex'}
# {'name': 'Adaira', 'gender': 'girl'}
# {'name': 'Adaire', 'gender': 'unisex'}
# {'name': 'Adaire', 'gender': 'unisex'}
# {'name': 'Adal', 'gender': 'girl'}
# {'name': 'Adala', 'gender': 'girl'}
# {'name': 'Adalaide', 'gender': 'girl'}
# {'name': 'Adalane', 'gender': 'girl'}
# {'name': 'Adalard', 'gender': 'boy'}
# (14, 65)
# https://nameberry.com/search?page=14&per_page=30&starts_with=A
# {'name': 'Adalayde', 'gender': 'girl'}
# {'name': 'Adalberto', 'gender': 'boy'}
# {'name': 'Adalea', 'gender': 'girl'}
# {'name': 'Adaleah', 'gender': 'girl'}
# {'name': 'Adalee', 'gender': 'girl'}
# {'name': 'Adaleigh', 'gender': 'girl'}
# {'name': 'Adalene', 'gender': 'girl'}
# {'name': 'Adalfo', 'gender': 'boy'}
# {'name': 'Adali', 'gender': 'girl'}
# {'name': 'Adalia', 'gender': 'girl'}
# {'name': 'Adaliah', 'gender': 'girl'}
# {'name': 'Adalie', 'gender': 'girl'}
# {'name': 'Adalin', 'gender': 'girl'}
# {'name': 'Adalina', 'gender': 'girl'}
# {'name': 'Adaline', 'gender': 'girl'}
# {'name': 'Adalinn', 'gender': 'girl'}
# {'name': 'Adalius', 'gender': 'boy'}
# {'name': 'Adalley', 'gender': 'girl'}
# {'name': 'Adallina', 'gender': 'girl'}
# {'name': 'Adalrich', 'gender': 'boy'}
# {'name': 'Adaly', 'gender': 'girl'}
# {'name': 'Adalya', 'gender': 'girl'}
# {'name': 'Adalyah', 'gender': 'girl'}
# {'name': 'Adalyn', 'gender': 'girl'}
# {'name': 'Adalynn', 'gender': 'girl'}
# {'name': 'Adalynne', 'gender': 'girl'}
# {'name': 'Adam', 'gender': 'boy'}
# {'name': 'Adama', 'gender': 'girl'}
# {'name': 'Adamah', 'gender': 'girl'}
# {'name': 'Adamaris', 'gender': 'girl'}
# (15, 65)
# https://nameberry.com/search?page=15&per_page=30&starts_with=A
# {'name': 'Adamec', 'gender': 'boy'}
# {'name': 'Adameena', 'gender': 'girl'}
# {'name': 'Adamek', 'gender': 'boy'}
# {'name': 'Adamik', 'gender': 'boy'}
# {'name': 'Adamina', 'gender': 'girl'}
# {'name': 'Adamine', 'gender': 'girl'}
# {'name': 'Adaminna', 'gender': 'girl'}
# {'name': 'Adamka', 'gender': 'boy'}
# {'name': 'Adamki', 'gender': 'boy'}
# {'name': 'Adamo', 'gender': 'boy'}
# {'name': 'Adamok', 'gender': 'boy'}
# {'name': 'Adams', 'gender': 'boy'}
# {'name': 'Adan', 'gender': 'unisex'}
# {'name': 'Adan', 'gender': 'unisex'}
# {'name': 'Adann', 'gender': 'girl'}
# {'name': 'Adanne', 'gender': 'girl'}
# {'name': 'Adaora', 'gender': 'girl'}
# {'name': 'Adar', 'gender': 'girl'}
# {'name': 'Adara', 'gender': 'girl'}
# {'name': 'Adarae', 'gender': 'girl'}
# {'name': 'Adarah', 'gender': 'girl'}
# {'name': 'Adare', 'gender': 'unisex'}
# {'name': 'Adare', 'gender': 'unisex'}
# {'name': 'Adaria', 'gender': 'girl'}
# {'name': 'Adarra', 'gender': 'girl'}
# {'name': 'Adas', 'gender': 'boy'}
# {'name': 'Adasha', 'gender': 'girl'}
# {'name': 'Aday', 'gender': 'girl'}
# {'name': 'Adaya', 'gender': 'girl'}
# (16, 65)
# https://nameberry.com/search?page=16&per_page=30&starts_with=A
# {'name': 'Adayre', 'gender': 'unisex'}
# {'name': 'Adayre', 'gender': 'unisex'}
# {'name': 'Add', 'gender': 'boy'}
# {'name': 'Adda', 'gender': 'girl'}
# {'name': 'Addah', 'gender': 'girl'}
# {'name': 'Addal', 'gender': 'girl'}
# {'name': 'Addala', 'gender': 'girl'}
# {'name': 'Addalla', 'gender': 'girl'}
# {'name': 'Addaly', 'gender': 'girl'}
# {'name': 'Addalyn', 'gender': 'girl'}
# {'name': 'Addalynn', 'gender': 'girl'}
# {'name': 'Addar', 'gender': 'boy'}
# {'name': 'Addax', 'gender': 'unisex'}
# {'name': 'Addax', 'gender': 'unisex'}
# {'name': 'Adde', 'gender': 'girl'}
# {'name': 'Addee', 'gender': 'girl'}
# {'name': 'Addelyn', 'gender': 'girl'}
# {'name': 'Addey', 'gender': 'girl'}
# {'name': 'Addi', 'gender': 'girl'}
# {'name': 'Addia', 'gender': 'girl'}
# {'name': 'Addiah', 'gender': 'girl'}
# {'name': 'Addie', 'gender': 'girl'}
# {'name': 'Addilyn', 'gender': 'girl'}
# {'name': 'Addilynn', 'gender': 'girl'}
# {'name': 'Addis', 'gender': 'unisex'}
# {'name': 'Addis', 'gender': 'unisex'}
# {'name': 'Addisen', 'gender': 'unisex'}
# {'name': 'Addisen', 'gender': 'unisex'}
# {'name': 'Addison', 'gender': 'unisex'}
# {'name': 'Addison', 'gender': 'unisex'}
# (17, 65)
# https://nameberry.com/search?page=17&per_page=30&starts_with=A
# {'name': 'Addisson', 'gender': 'unisex'}
# {'name': 'Addisson', 'gender': 'unisex'}
# {'name': 'Addisyn', 'gender': 'girl'}
# {'name': 'Addonis', 'gender': 'boy'}
# {'name': 'Addy', 'gender': 'girl'}
# {'name': 'Addysen', 'gender': 'boy'}
# {'name': 'Addyson', 'gender': 'unisex'}
# {'name': 'Addyson', 'gender': 'unisex'}
# {'name': 'Ade', 'gender': 'unisex'}
# {'name': 'Ade', 'gender': 'unisex'}
# {'name': 'Adecyn', 'gender': 'girl'}
# {'name': 'Adee', 'gender': 'girl'}
# {'name': 'Adei', 'gender': 'girl'}
# {'name': 'Adel', 'gender': 'unisex'}
# {'name': 'Adel', 'gender': 'unisex'}
# {'name': 'Adela', 'gender': 'girl'}
# {'name': 'Adelade', 'gender': 'girl'}
# {'name': 'Adelaid', 'gender': 'girl'}
# {'name': 'Adelaida', 'gender': 'girl'}
# {'name': 'Adelaide', 'gender': 'girl'}
# {'name': 'Adelaine', 'gender': 'girl'}
# {'name': 'Adelais', 'gender': 'girl'}
# {'name': 'Adelard', 'gender': 'boy'}
# {'name': 'Adelbert', 'gender': 'boy'}
# {'name': 'Adele', 'gender': 'girl'}
# {'name': 'Adelei', 'gender': 'girl'}
# {'name': 'Adelfa', 'gender': 'girl'}
# {'name': 'Adelfia', 'gender': 'girl'}
# {'name': 'Adelheid', 'gender': 'girl'}
# {'name': 'Adelia', 'gender': 'girl'}
# (18, 65)
# https://nameberry.com/search?page=18&per_page=30&starts_with=A
# {'name': 'Adeliade', 'gender': 'girl'}
# {'name': 'Adeliah', 'gender': 'girl'}
# {'name': 'Adelice', 'gender': 'girl'}
# {'name': 'Adelicia', 'gender': 'girl'}
# {'name': 'Adelie', 'gender': 'girl'}
# {'name': 'Adelin', 'gender': 'girl'}
# {'name': 'Adelina', 'gender': 'girl'}
# {'name': 'Adelind', 'gender': 'girl'}
# {'name': 'Adeline', 'gender': 'girl'}
# {'name': 'Adelio', 'gender': 'boy'}
# {'name': 'Adelis', 'gender': 'girl'}
# {'name': 'Adelisa', 'gender': 'girl'}
# {'name': 'Adelita', 'gender': 'girl'}
# {'name': 'Adeliya', 'gender': 'girl'}
# {'name': 'Adeliza', 'gender': 'girl'}
# {'name': 'Adelka', 'gender': 'girl'}
# {'name': 'Adell', 'gender': 'girl'}
# {'name': 'Adella', 'gender': 'girl'}
# {'name': 'Adellah', 'gender': 'girl'}
# {'name': 'Adelle', 'gender': 'girl'}
# {'name': 'Adelma', 'gender': 'girl'}
# {'name': 'Adelpha', 'gender': 'girl'}
# {'name': 'Adelphia', 'gender': 'girl'}
# {'name': 'Adelvice', 'gender': 'girl'}
# {'name': 'Adelvicia', 'gender': 'girl'}
# {'name': 'Adelya', 'gender': 'girl'}
# {'name': 'Adelyn', 'gender': 'girl'}
# {'name': 'Adelynn', 'gender': 'girl'}
# {'name': 'Adelynne', 'gender': 'girl'}
# {'name': 'Adem', 'gender': 'boy'}
# (19, 65)
# https://nameberry.com/search?page=19&per_page=30&starts_with=A
# {'name': 'Adema', 'gender': 'girl'}
# {'name': 'Ademar', 'gender': 'boy'}
# {'name': 'Ademeena', 'gender': 'girl'}
# {'name': 'Ademina', 'gender': 'girl'}
# {'name': 'Aden', 'gender': 'unisex'}
# {'name': 'Aden', 'gender': 'unisex'}
# {'name': 'Adena', 'gender': 'girl'}
# {'name': 'Adeon', 'gender': 'boy'}
# {'name': 'Adephine', 'gender': 'girl'}
# {'name': 'Aderyn', 'gender': 'girl'}
# {'name': 'Adesha', 'gender': 'girl'}
# {'name': 'Adeshia', 'gender': 'girl'}
# {'name': 'Adessa', 'gender': 'girl'}
# {'name': 'Adessia', 'gender': 'girl'}
# {'name': 'Adette', 'gender': 'girl'}
# {'name': 'Adey', 'gender': 'girl'}
# {'name': 'Adeye', 'gender': 'girl'}
# {'name': 'Adham', 'gender': 'boy'}
# {'name': 'Adhara', 'gender': 'girl'}
# {'name': 'Adhit', 'gender': 'boy'}
# {'name': 'Adi', 'gender': 'unisex'}
# {'name': 'Adi', 'gender': 'unisex'}
# {'name': 'Adia', 'gender': 'girl'}
# {'name': 'Adiah', 'gender': 'girl'}
# {'name': 'Adie', 'gender': 'girl'}
# {'name': 'Adiel', 'gender': 'boy'}
# {'name': 'Adil', 'gender': 'boy'}
# {'name': 'Adile', 'gender': 'girl'}
# {'name': 'Adilene', 'gender': 'girl'}
# {'name': 'Adilyn', 'gender': 'girl'}
# (20, 65)
# https://nameberry.com/search?page=20&per_page=30&starts_with=A
# {'name': 'Adilynn', 'gender': 'girl'}
# {'name': 'Adin', 'gender': 'unisex'}
# {'name': 'Adin', 'gender': 'unisex'}
# {'name': 'Adina', 'gender': 'girl'}
# {'name': 'Adinah', 'gender': 'girl'}
# {'name': 'Adine', 'gender': 'girl'}
# {'name': 'Adino', 'gender': 'boy'}
# {'name': 'Adir', 'gender': 'boy'}
# {'name': 'Adira', 'gender': 'girl'}
# {'name': 'Adis', 'gender': 'girl'}
# {'name': 'Adisa', 'gender': 'girl'}
# {'name': 'Adisen', 'gender': 'unisex'}
# {'name': 'Adisen', 'gender': 'unisex'}
# {'name': 'Adison', 'gender': 'unisex'}
# {'name': 'Adison', 'gender': 'unisex'}
# {'name': 'Adisynne', 'gender': 'girl'}
# {'name': 'Aditya', 'gender': 'boy'}
# {'name': 'Adiv', 'gender': 'boy'}
# {'name': 'Adlai', 'gender': 'boy'}
# {'name': 'Adlay', 'gender': 'boy'}
# {'name': 'Adler', 'gender': 'boy'}
# {'name': 'Adley', 'gender': 'unisex'}
# {'name': 'Adley', 'gender': 'unisex'}
# {'name': 'Adlin', 'gender': 'unisex'}
# {'name': 'Adlin', 'gender': 'unisex'}
# {'name': 'Adlina', 'gender': 'girl'}
# {'name': 'Adline', 'gender': 'girl'}
# {'name': 'Adlyn', 'gender': 'girl'}
# {'name': 'Adlynn', 'gender': 'girl'}
# {'name': 'Admiral', 'gender': 'boy'}
# (21, 65)
# https://nameberry.com/search?page=21&per_page=30&starts_with=A
# {'name': 'Admundo', 'gender': 'boy'}
# {'name': 'Adna', 'gender': 'girl'}
# {'name': 'Adnan', 'gender': 'boy'}
# {'name': 'Adnisha', 'gender': 'girl'}
# {'name': 'Adnon', 'gender': 'boy'}
# {'name': 'Ado', 'gender': 'girl'}
# {'name': 'Adok', 'gender': 'boy'}
# {'name': 'Adolf', 'gender': 'boy'}
# {'name': 'Adolfa', 'gender': 'girl'}
# {'name': 'Adolfo', 'gender': 'boy'}
# {'name': 'Adollfa', 'gender': 'girl'}
# {'name': 'Adolph', 'gender': 'boy'}
# {'name': 'Adolpha', 'gender': 'girl'}
# {'name': 'Adolphe', 'gender': 'boy'}
# {'name': 'Adolphus', 'gender': 'boy'}
# {'name': 'Adomas', 'gender': 'boy'}
# {'name': 'Adon', 'gender': 'girl'}
# {'name': 'Adonijah', 'gender': 'boy'}
# {'name': 'Adonis', 'gender': 'boy'}
# {'name': 'Adora', 'gender': 'girl'}
# {'name': 'Adorabelle', 'gender': 'girl'}
# {'name': 'Adorae', 'gender': 'girl'}
# {'name': 'Adoray', 'gender': 'girl'}
# {'name': 'Adore', 'gender': 'girl'}
# {'name': 'Adoree', 'gender': 'girl'}
# {'name': 'Adoria', 'gender': 'girl'}
# {'name': 'Adorjan', 'gender': 'boy'}
# {'name': 'Adorlee', 'gender': 'girl'}
# {'name': 'Adra', 'gender': 'girl'}
# {'name': 'Adrain', 'gender': 'boy'}
# (22, 65)
# https://nameberry.com/search?page=22&per_page=30&starts_with=A
# {'name': 'Adrastea', 'gender': 'girl'}
# {'name': 'Adrea', 'gender': 'girl'}
# {'name': 'Adrean', 'gender': 'boy'}
# {'name': 'Adreana', 'gender': 'girl'}
# {'name': 'Adreanna', 'gender': 'girl'}
# {'name': 'Adreea', 'gender': 'girl'}
# {'name': 'Adrey', 'gender': 'girl'}
# {'name': 'Adria', 'gender': 'unisex'}
# {'name': 'Adria', 'gender': 'unisex'}
# {'name': 'Adriah', 'gender': 'girl'}
# {'name': 'Adrian', 'gender': 'boy'}
# {'name': 'Adriana', 'gender': 'girl'}
# {'name': 'Adrianah', 'gender': 'girl'}
# {'name': 'Adriane', 'gender': 'girl'}
# {'name': 'Adrianna', 'gender': 'girl'}
# {'name': 'Adriannah', 'gender': 'girl'}
# {'name': 'Adrianne', 'gender': 'girl'}
# {'name': 'Adriano', 'gender': 'boy'}
# {'name': 'Adrie', 'gender': 'girl'}
# {'name': 'Adrieanne', 'gender': 'girl'}
# {'name': 'Adriel', 'gender': 'boy'}
# {'name': 'Adrien', 'gender': 'unisex'}
# {'name': 'Adrien', 'gender': 'unisex'}
# {'name': 'Adriena', 'gender': 'girl'}
# {'name': 'Adrienah', 'gender': 'girl'}
# {'name': 'Adriene', 'gender': 'girl'}
# {'name': 'Adrienna', 'gender': 'girl'}
# {'name': 'Adrienne', 'gender': 'girl'}
# {'name': 'Adrina', 'gender': 'girl'}
# {'name': 'Adriyanna', 'gender': 'girl'}
# (23, 65)
# https://nameberry.com/search?page=23&per_page=30&starts_with=A
# {'name': 'Adron', 'gender': 'boy'}
# {'name': 'Aduke', 'gender': 'girl'}
# {'name': 'Adwoa', 'gender': 'girl'}
# {'name': 'Ady', 'gender': 'girl'}
# {'name': 'Adyan', 'gender': 'boy'}
# {'name': 'Adyn', 'gender': 'girl'}
# {'name': 'Adynn', 'gender': 'girl'}
# {'name': 'Adynne', 'gender': 'girl'}
# {'name': 'Adysen', 'gender': 'unisex'}
# {'name': 'Adysen', 'gender': 'unisex'}
# {'name': 'Adyson', 'gender': 'girl'}
# {'name': 'Aed', 'gender': 'boy'}
# {'name': 'Aedan', 'gender': 'boy'}
# {'name': 'Aeddan', 'gender': 'boy'}
# {'name': 'Aedin', 'gender': 'boy'}
# {'name': 'Aeeda', 'gender': 'girl'}
# {'name': 'Aeesha', 'gender': 'girl'}
# {'name': 'Aeeshah', 'gender': 'girl'}
# {'name': 'Aegeus', 'gender': 'boy'}
# {'name': 'Aegis', 'gender': 'boy'}
# {'name': 'Aelani', 'gender': 'girl'}
# {'name': 'Aeldred', 'gender': 'boy'}
# {'name': 'Aeliana', 'gender': 'girl'}
# (24, 65)
# https://nameberry.com/search?page=24&per_page=30&starts_with=A
# {'name': 'Aelicia', 'gender': 'girl'}
# {'name': 'Aella', 'gender': 'girl'}
# {'name': 'Aemiley', 'gender': 'girl'}
# {'name': 'Aemilia', 'gender': 'girl'}
# {'name': 'Aemilie', 'gender': 'girl'}
# {'name': 'Aemilio', 'gender': 'boy'}
# {'name': 'Aenea', 'gender': 'girl'}
# {'name': 'Aeneas', 'gender': 'boy'}
# {'name': 'Aengus', 'gender': 'boy'}
# {'name': 'Aenya', 'gender': 'girl'}
# {'name': 'Aer', 'gender': 'girl'}
# {'name': 'Aeran', 'gender': 'girl'}
# {'name': 'Aerenne', 'gender': 'girl'}
# {'name': 'Aerial', 'gender': 'girl'}
# {'name': 'Aeriale', 'gender': 'girl'}
# {'name': 'Aeriana', 'gender': 'girl'}
# {'name': 'Aerianna', 'gender': 'girl'}
# {'name': 'Aeric', 'gender': 'boy'}
# {'name': 'Aerica', 'gender': 'girl'}
# {'name': 'Aerick', 'gender': 'boy'}
# {'name': 'Aericka', 'gender': 'girl'}
# {'name': 'Aeriel', 'gender': 'girl'}
# {'name': 'Aeriela', 'gender': 'girl'}
# {'name': 'Aeriell', 'gender': 'girl'}
# {'name': 'Aerimus', 'gender': 'boy'}
# {'name': 'Aerin', 'gender': 'girl'}
# {'name': 'Aerionna', 'gender': 'girl'}
# {'name': 'Aerith', 'gender': 'girl'}
# {'name': 'Aeron', 'gender': 'unisex'}
# {'name': 'Aeron', 'gender': 'unisex'}
# (25, 65)
# https://nameberry.com/search?page=25&per_page=30&starts_with=A
# {'name': 'Aeronwen', 'gender': 'girl'}
# {'name': 'Aeronwy', 'gender': 'girl'}
# {'name': 'Aerric', 'gender': 'boy'}
# {'name': 'Aerrick', 'gender': 'boy'}
# {'name': 'Aerricko', 'gender': 'boy'}
# {'name': 'Aeryal', 'gender': 'girl'}
# {'name': 'Aeryn', 'gender': 'girl'}
# {'name': 'Aesha', 'gender': 'girl'}
# {'name': 'Aeshah', 'gender': 'girl'}
# {'name': 'Aesop', 'gender': 'boy'}
# {'name': 'Aeta', 'gender': 'girl'}
# {'name': 'Aeva', 'gender': 'girl'}
# {'name': 'Affan', 'gender': 'boy'}
# {'name': 'Affera', 'gender': 'girl'}
# {'name': 'Affery', 'gender': 'girl'}
# {'name': 'Affie', 'gender': 'girl'}
# {'name': 'Affinity', 'gender': 'girl'}
# {'name': 'Affonso', 'gender': 'boy'}
# {'name': 'Affra', 'gender': 'girl'}
# {'name': 'Affrey', 'gender': 'girl'}
# {'name': 'Affrica', 'gender': 'girl'}
# {'name': 'Affricah', 'gender': 'girl'}
# {'name': 'Affrie', 'gender': 'girl'}
# {'name': 'Affrika', 'gender': 'girl'}
# {'name': 'Affrikah', 'gender': 'girl'}
# {'name': 'Affton', 'gender': 'girl'}
# {'name': 'Afia', 'gender': 'girl'}
# {'name': 'Afonso', 'gender': 'boy'}
# {'name': 'Afra', 'gender': 'girl'}
# {'name': 'Afraa', 'gender': 'girl'}
# (26, 65)
# https://nameberry.com/search?page=26&per_page=30&starts_with=A
# {'name': 'Afric', 'gender': 'girl'}
# {'name': 'Africa', 'gender': 'girl'}
# {'name': 'Africah', 'gender': 'girl'}
# {'name': 'Africaya', 'gender': 'girl'}
# {'name': 'Africia', 'gender': 'girl'}
# {'name': 'Africiana', 'gender': 'girl'}
# {'name': 'Afrika', 'gender': 'girl'}
# {'name': 'Afrikah', 'gender': 'girl'}
# {'name': 'Afrodita', 'gender': 'girl'}
# {'name': 'Afrodite', 'gender': 'girl'}
# {'name': 'Aftan', 'gender': 'girl'}
# {'name': 'Aften', 'gender': 'girl'}
# {'name': 'Afternoon', 'gender': 'girl'}
# {'name': 'Aftin', 'gender': 'girl'}
# {'name': 'Aftine', 'gender': 'girl'}
# {'name': 'Aftinn', 'gender': 'girl'}
# {'name': 'Afton', 'gender': 'girl'}
# {'name': 'Aftonn', 'gender': 'girl'}
# {'name': 'Aftonne', 'gender': 'girl'}
# {'name': 'Aftyn', 'gender': 'girl'}
# {'name': 'Aftynn', 'gender': 'girl'}
# {'name': 'Afua', 'gender': 'girl'}
# {'name': 'Ag', 'gender': 'girl'}
# {'name': 'Agace', 'gender': 'girl'}
# {'name': 'Agacia', 'gender': 'girl'}
# {'name': 'Agafia', 'gender': 'girl'}
# {'name': 'Agaistin', 'gender': 'boy'}
# {'name': 'Agapi', 'gender': 'girl'}
# {'name': 'Agasha', 'gender': 'girl'}
# {'name': 'Agassi', 'gender': 'boy'}
# (27, 65)
# https://nameberry.com/search?page=27&per_page=30&starts_with=A
# {'name': 'Agata', 'gender': 'girl'}
# {'name': 'Agatah', 'gender': 'girl'}
# {'name': 'Agate', 'gender': 'girl'}
# {'name': 'Agatha', 'gender': 'girl'}
# {'name': 'Agathe', 'gender': 'girl'}
# {'name': 'Agathi', 'gender': 'girl'}
# {'name': 'Agatta', 'gender': 'girl'}
# {'name': 'Agetha', 'gender': 'girl'}
# {'name': 'Aggi', 'gender': 'girl'}
# {'name': 'Aggie', 'gender': 'girl'}
# {'name': 'Aggy', 'gender': 'girl'}
# {'name': 'Aggye', 'gender': 'girl'}
# {'name': 'Aghavni', 'gender': 'girl'}
# {'name': 'Agi', 'gender': 'girl'}
# {'name': 'Agidius', 'gender': 'boy'}
# {'name': 'Agie', 'gender': 'girl'}
# {'name': 'Aglaea', 'gender': 'girl'}
# {'name': 'Agna', 'gender': 'girl'}
# {'name': 'Agne', 'gender': 'girl'}
# {'name': 'Agnek', 'gender': 'girl'}
# {'name': 'Agnella', 'gender': 'girl'}
# {'name': 'Agnes', 'gender': 'girl'}
# {'name': 'Agnesa', 'gender': 'girl'}
# {'name': 'Agnesca', 'gender': 'girl'}
# {'name': 'Agnese', 'gender': 'girl'}
# {'name': 'Agnesina', 'gender': 'girl'}
# {'name': 'Agneska', 'gender': 'girl'}
# {'name': 'Agness', 'gender': 'girl'}
# {'name': 'Agnessa', 'gender': 'girl'}
# (28, 65)
# https://nameberry.com/search?page=28&per_page=30&starts_with=A
# {'name': 'Agnesse', 'gender': 'girl'}
# {'name': 'Agnessina', 'gender': 'girl'}
# {'name': 'Agneta', 'gender': 'girl'}
# {'name': 'Agnethe', 'gender': 'girl'}
# {'name': 'Agni', 'gender': 'boy'}
# {'name': 'Agnia', 'gender': 'girl'}
# {'name': 'Agnieszka', 'gender': 'girl'}
# {'name': 'Agnis', 'gender': 'girl'}
# {'name': 'Agnola', 'gender': 'girl'}
# {'name': 'Agnus', 'gender': 'girl'}
# {'name': 'Agostino', 'gender': 'boy'}
# {'name': 'Agosto', 'gender': 'boy'}
# {'name': 'Agoston', 'gender': 'boy'}
# {'name': 'Agota', 'gender': 'girl'}
# {'name': 'Agotha', 'gender': 'girl'}
# {'name': 'Agraciana', 'gender': 'girl'}
# {'name': 'Agracianna', 'gender': 'girl'}
# {'name': 'Agrafena', 'gender': 'girl'}
# {'name': 'Agrafina', 'gender': 'girl'}
# {'name': 'Agrippa', 'gender': 'girl'}
# {'name': 'Agrippina', 'gender': 'girl'}
# {'name': 'Agrippine', 'gender': 'girl'}
# {'name': 'Agu', 'gender': 'boy'}
# {'name': 'Agueda', 'gender': 'girl'}
# {'name': 'Aguistin', 'gender': 'boy'}
# {'name': 'Agung', 'gender': 'boy'}
# {'name': 'Agusta', 'gender': 'girl'}
# {'name': 'Agustin', 'gender': 'boy'}
# {'name': 'Agusto', 'gender': 'boy'}
# {'name': 'Agustus', 'gender': 'boy'}
# (29, 65)
# https://nameberry.com/search?page=29&per_page=30&starts_with=A
# {'name': 'Agusztav', 'gender': 'boy'}
# {'name': 'Agy', 'gender': 'girl'}
# {'name': 'Agye', 'gender': 'girl'}
# {'name': 'Agyness', 'gender': 'girl'}
# {'name': 'Ah', 'gender': 'boy'}
# {'name': 'Ahaan', 'gender': 'boy'}
# {'name': 'Ahab', 'gender': 'boy'}
# {'name': 'Aharon', 'gender': 'boy'}
# {'name': 'Ahava', 'gender': 'girl'}
# {'name': 'Ahdella', 'gender': 'girl'}
# {'name': 'Ahearne', 'gender': 'boy'}
# {'name': 'Aheesha', 'gender': 'girl'}
# {'name': 'Ahenio', 'gender': 'boy'}
# {'name': 'Aherin', 'gender': 'boy'}
# {'name': 'Ahern', 'gender': 'boy'}
# {'name': 'Aherne', 'gender': 'boy'}
# {'name': 'Ahjah', 'gender': 'girl'}
# {'name': 'Ahlexis', 'gender': 'girl'}
# {'name': 'Ahlyssa', 'gender': 'girl'}
# {'name': 'Ahmad', 'gender': 'boy'}
# {'name': 'Ahmalia', 'gender': 'girl'}
# {'name': 'Ahman', 'gender': 'boy'}
# {'name': 'Ahmani', 'gender': 'girl'}
# {'name': 'Ahmber', 'gender': 'girl'}
# {'name': 'Ahmed', 'gender': 'boy'}
# {'name': 'Ahmet', 'gender': 'boy'}
# {'name': 'Ahmir', 'gender': 'boy'}
# {'name': 'Ahmod', 'gender': 'boy'}
# {'name': 'Ahna', 'gender': 'girl'}
# {'name': 'Ahnna', 'gender': 'girl'}
# (30, 65)
# https://nameberry.com/search?page=30&per_page=30&starts_with=A
# {'name': 'Ahraya', 'gender': 'girl'}
# {'name': 'Ahreanna', 'gender': 'girl'}
# {'name': 'Ahriana', 'gender': 'girl'}
# {'name': 'Ahrianna', 'gender': 'girl'}
# {'name': 'Ahriel', 'gender': 'girl'}
# {'name': 'Ahron', 'gender': 'boy'}
# {'name': 'Ahshlee', 'gender': 'girl'}
# {'name': 'Ahsia', 'gender': 'girl'}
# {'name': 'Ahyana', 'gender': 'girl'}
# {'name': 'Aiasha', 'gender': 'girl'}
# {'name': 'Aibhilin', 'gender': 'girl'}
# {'name': 'Aibhlin', 'gender': 'girl'}
# {'name': 'Aibileen', 'gender': 'girl'}
# {'name': 'Aida', 'gender': 'girl'}
# {'name': 'Aidah', 'gender': 'girl'}
# {'name': 'Aidan', 'gender': 'unisex'}
# {'name': 'Aidan', 'gender': 'unisex'}
# {'name': 'Aidana', 'gender': 'girl'}
# {'name': 'Aidann', 'gender': 'girl'}
# {'name': 'Aidanna', 'gender': 'girl'}
# {'name': 'Aidanne', 'gender': 'girl'}
# {'name': 'Aide', 'gender': 'girl'}
# {'name': 'Aidee', 'gender': 'girl'}
# {'name': 'Aideen', 'gender': 'girl'}
# {'name': 'Aiden', 'gender': 'unisex'}
# {'name': 'Aiden', 'gender': 'unisex'}
# {'name': 'Aidena', 'gender': 'girl'}
# {'name': 'Aidin', 'gender': 'girl'}
# {'name': 'Aidina', 'gender': 'girl'}
# (31, 65)
# https://nameberry.com/search?page=31&per_page=30&starts_with=A
# {'name': 'Aidine', 'gender': 'girl'}
# {'name': 'Aidon', 'gender': 'girl'}
# {'name': 'Aidrian', 'gender': 'boy'}
# {'name': 'Aidy', 'gender': 'girl'}
# {'name': 'Aidyn', 'gender': 'unisex'}
# {'name': 'Aidyn', 'gender': 'unisex'}
# {'name': 'Aidynn', 'gender': 'girl'}
# {'name': 'Aidynne', 'gender': 'girl'}
# {'name': 'Aiesha', 'gender': 'girl'}
# {'name': 'Aieshah', 'gender': 'girl'}
# {'name': 'Aife', 'gender': 'girl'}
# {'name': 'Aifric', 'gender': 'girl'}
# {'name': 'Aifrica', 'gender': 'girl'}
# {'name': 'Aija', 'gender': 'girl'}
# {'name': 'Aijah', 'gender': 'girl'}
# {'name': 'Aijiah', 'gender': 'girl'}
# {'name': 'Aikaterine', 'gender': 'girl'}
# {'name': 'Aiken', 'gender': 'boy'}
# {'name': 'Aikiela', 'gender': 'girl'}
# {'name': 'Aikilah', 'gender': 'girl'}
# {'name': 'Aiko', 'gender': 'girl'}
# {'name': 'Aila', 'gender': 'girl'}
# {'name': 'Ailana', 'gender': 'girl'}
# {'name': 'Ailani', 'gender': 'girl'}
# {'name': 'Ailbert', 'gender': 'boy'}
# {'name': 'Ailbhe', 'gender': 'unisex'}
# {'name': 'Ailbhe', 'gender': 'unisex'}
# {'name': 'Aileah', 'gender': 'girl'}
# {'name': 'Ailean', 'gender': 'boy'}
# (32, 65)
# https://nameberry.com/search?page=32&per_page=30&starts_with=A
# {'name': 'Aileas', 'gender': 'girl'}
# {'name': 'Aileen', 'gender': 'girl'}
# {'name': 'Ailene', 'gender': 'girl'}
# {'name': 'Ailfrid', 'gender': 'boy'}
# {'name': 'Aili', 'gender': 'girl'}
# {'name': 'Ailin', 'gender': 'boy'}
# {'name': 'Ailinn', 'gender': 'girl'}
# {'name': 'Ailis', 'gender': 'girl'}
# {'name': 'Ailish', 'gender': 'girl'}
# {'name': 'Ailla', 'gender': 'girl'}
# {'name': 'Ailsa', 'gender': 'girl'}
# {'name': 'Aimar', 'gender': 'boy'}
# {'name': 'Aime', 'gender': 'girl'}
# {'name': 'Aimee', 'gender': 'girl'}
# {'name': 'Aimey', 'gender': 'girl'}
# {'name': 'Aimi', 'gender': 'girl'}
# {'name': 'Aimia', 'gender': 'girl'}
# {'name': 'Aimie', 'gender': 'girl'}
# {'name': 'Aimil', 'gender': 'unisex'}
# {'name': 'Aimil', 'gender': 'unisex'}
# {'name': 'Aimilia', 'gender': 'girl'}
# {'name': 'Aimiliona', 'gender': 'girl'}
# {'name': 'Aimilios', 'gender': 'unisex'}
# {'name': 'Aimilios', 'gender': 'unisex'}
# {'name': 'Aimon', 'gender': 'boy'}
# {'name': 'Aimy', 'gender': 'girl'}
# {'name': 'Aina', 'gender': 'girl'}
# {'name': 'Ainara', 'gender': 'girl'}
# (33, 65)
# https://nameberry.com/search?page=33&per_page=30&starts_with=A
# {'name': 'Aindrea', 'gender': 'girl'}
# {'name': 'Aine', 'gender': 'girl'}
# {'name': 'Aineus', 'gender': 'boy'}
# {'name': 'Aingeal', 'gender': 'boy'}
# {'name': 'Ainhoa', 'gender': 'girl'}
# {'name': 'Ainneus', 'gender': 'boy'}
# {'name': 'Aino', 'gender': 'girl'}
# {'name': 'Ainslea', 'gender': 'girl'}
# {'name': 'Ainslee', 'gender': 'girl'}
# {'name': 'Ainsleigh', 'gender': 'girl'}
# {'name': 'Ainsley', 'gender': 'unisex'}
# {'name': 'Ainsley', 'gender': 'unisex'}
# {'name': 'Ainslie', 'gender': 'unisex'}
# {'name': 'Ainslie', 'gender': 'unisex'}
# {'name': 'Ainsly', 'gender': 'unisex'}
# {'name': 'Ainsly', 'gender': 'unisex'}
# {'name': 'Aintza', 'gender': 'girl'}
# {'name': 'Aio', 'gender': 'boy'}
# {'name': 'Aipril', 'gender': 'girl'}
# {'name': 'Air', 'gender': 'girl'}
# {'name': 'Aira', 'gender': 'girl'}
# {'name': 'Airamis', 'gender': 'boy'}
# {'name': 'Aire', 'gender': 'girl'}
# {'name': 'Aireal', 'gender': 'girl'}
# {'name': 'Airial', 'gender': 'girl'}
# {'name': 'Airiana', 'gender': 'girl'}
# {'name': 'Airicka', 'gender': 'girl'}
# {'name': 'Airika', 'gender': 'girl'}
# {'name': 'Airin', 'gender': 'girl'}
# {'name': 'Airini', 'gender': 'girl'}
# (34, 65)
# https://nameberry.com/search?page=34&per_page=30&starts_with=A
# {'name': 'Airle', 'gender': 'boy'}
# {'name': 'Airlen', 'gender': 'girl'}
# {'name': 'Airlie', 'gender': 'boy'}
# {'name': 'Airton', 'gender': 'boy'}
# {'name': 'Aisa', 'gender': 'girl'}
# {'name': 'Aischa', 'gender': 'girl'}
# {'name': 'Aish', 'gender': 'girl'}
# {'name': 'Aisha', 'gender': 'girl'}
# {'name': 'Aishah', 'gender': 'girl'}
# {'name': 'Aisheh', 'gender': 'girl'}
# {'name': 'Aishellyn', 'gender': 'girl'}
# {'name': 'Aishia', 'gender': 'girl'}
# {'name': 'Aishiah', 'gender': 'girl'}
# {'name': 'Aishlee', 'gender': 'girl'}
# {'name': 'Aishlinn', 'gender': 'girl'}
# {'name': 'Aishwarya', 'gender': 'girl'}
# {'name': 'Aisia', 'gender': 'girl'}
# {'name': 'Aisiah', 'gender': 'girl'}
# {'name': 'Aisian', 'gender': 'girl'}
# {'name': 'Aislee', 'gender': 'girl'}
# {'name': 'Aisley', 'gender': 'girl'}
# {'name': 'Aislin', 'gender': 'girl'}
# {'name': 'Aisling', 'gender': 'girl'}
# {'name': 'Aislinn', 'gender': 'girl'}
# {'name': 'Aislyn', 'gender': 'girl'}
# {'name': 'Aislynne', 'gender': 'girl'}
# {'name': 'Aitan', 'gender': 'boy'}
# {'name': 'Aitana', 'gender': 'girl'}
# {'name': 'Aither', 'gender': 'boy'}
# (35, 65)
# https://nameberry.com/search?page=35&per_page=30&starts_with=A
# {'name': 'Aithne', 'gender': 'girl'}
# {'name': 'Aithnea', 'gender': 'girl'}
# {'name': 'Aitne', 'gender': 'girl'}
# {'name': 'Aitor', 'gender': 'boy'}
# {'name': 'Aitzpea', 'gender': 'girl'}
# {'name': 'Aiva', 'gender': 'girl'}
# {'name': 'Aivree', 'gender': 'girl'}
# {'name': 'Aixa', 'gender': 'girl'}
# {'name': 'Aiyana', 'gender': 'girl'}
# {'name': 'Aiyanna', 'gender': 'girl'}
# {'name': 'Aiyesha', 'gender': 'girl'}
# {'name': 'Aiyla', 'gender': 'girl'}
# {'name': 'Aiysha', 'gender': 'girl'}
# {'name': 'Aiza', 'gender': 'girl'}
# {'name': 'Aizah', 'gender': 'girl'}
# {'name': 'Aizha', 'gender': 'girl'}
# {'name': 'Aizia', 'gender': 'girl'}
# {'name': 'Aizik', 'gender': 'boy'}
# {'name': 'Aj', 'gender': 'boy'}
# {'name': 'Aja', 'gender': 'unisex'}
# {'name': 'Aja', 'gender': 'unisex'}
# {'name': 'Ajada', 'gender': 'girl'}
# {'name': 'Ajah', 'gender': 'girl'}
# {'name': 'Ajamu', 'gender': 'boy'}
# {'name': 'Ajani', 'gender': 'boy'}
# {'name': 'Ajara', 'gender': 'girl'}
# {'name': 'Ajaran', 'gender': 'girl'}
# {'name': 'Ajare', 'gender': 'girl'}
# {'name': 'Ajaree', 'gender': 'girl'}
# {'name': 'Ajax', 'gender': 'boy'}
# (36, 65)
# https://nameberry.com/search?page=36&per_page=30&starts_with=A
# {'name': 'Ajay', 'gender': 'boy'}
# {'name': 'Ajhia', 'gender': 'girl'}
# {'name': 'Aji', 'gender': 'girl'}
# {'name': 'Ajia', 'gender': 'girl'}
# {'name': 'Ajjia', 'gender': 'girl'}
# {'name': 'Ajwa', 'gender': 'girl'}
# {'name': 'Akacia', 'gender': 'girl'}
# {'name': 'Akakia', 'gender': 'girl'}
# {'name': 'Akako', 'gender': 'girl'}
# {'name': 'Akamu', 'gender': 'boy'}
# {'name': 'Akasha', 'gender': 'girl'}
# {'name': 'Akavya', 'gender': 'boy'}
# {'name': 'Akaysha', 'gender': 'girl'}
# {'name': 'Akbar', 'gender': 'boy'}
# {'name': 'Akeela', 'gender': 'girl'}
# {'name': 'Akeelah', 'gender': 'girl'}
# {'name': 'Akeem', 'gender': 'boy'}
# {'name': 'Akeeva', 'gender': 'unisex'}
# {'name': 'Akeeva', 'gender': 'unisex'}
# {'name': 'Akeila', 'gender': 'girl'}
# {'name': 'Akeilah', 'gender': 'girl'}
# {'name': 'Akeiyla', 'gender': 'girl'}
# {'name': 'Akela', 'gender': 'unisex'}
# {'name': 'Akela', 'gender': 'unisex'}
# {'name': 'Akelina', 'gender': 'girl'}
# {'name': 'Akello', 'gender': 'boy'}
# {'name': 'Aken', 'gender': 'boy'}
# {'name': 'Akhylle', 'gender': 'boy'}
# {'name': 'Aki', 'gender': 'boy'}
# (37, 65)
# https://nameberry.com/search?page=37&per_page=30&starts_with=A
# {'name': 'Akib', 'gender': 'boy'}
# {'name': 'Akiba', 'gender': 'unisex'}
# {'name': 'Akiba', 'gender': 'unisex'}
# {'name': 'Akiela', 'gender': 'girl'}
# {'name': 'Akielah', 'gender': 'girl'}
# {'name': 'Akiko', 'gender': 'girl'}
# {'name': 'Akila', 'gender': 'girl'}
# {'name': 'Akilah', 'gender': 'girl'}
# {'name': 'Akilaih', 'gender': 'girl'}
# {'name': 'Akili', 'gender': 'girl'}
# {'name': 'Akilia', 'gender': 'girl'}
# {'name': 'Akilla', 'gender': 'girl'}
# {'name': 'Akillah', 'gender': 'girl'}
# {'name': 'Akilles', 'gender': 'boy'}
# {'name': 'Akim', 'gender': 'boy'}
# {'name': 'Akio', 'gender': 'boy'}
# {'name': 'Akira', 'gender': 'unisex'}
# {'name': 'Akira', 'gender': 'unisex'}
# {'name': 'Akiro', 'gender': 'boy'}
# {'name': 'Akiv', 'gender': 'boy'}
# {'name': 'Akiva', 'gender': 'unisex'}
# {'name': 'Akiva', 'gender': 'unisex'}
# {'name': 'Akkila', 'gender': 'girl'}
# {'name': 'Akkub', 'gender': 'boy'}
# {'name': 'Akkubian', 'gender': 'boy'}
# {'name': 'Akoni', 'gender': 'boy'}
# {'name': 'Akoobjee', 'gender': 'boy'}
# {'name': 'Akosua', 'gender': 'girl'}
# {'name': 'Akoub', 'gender': 'boy'}
# {'name': 'Akoubian', 'gender': 'boy'}
# (38, 65)
# https://nameberry.com/search?page=38&per_page=30&starts_with=A
# {'name': 'Akram', 'gender': 'boy'}
# {'name': 'Aksel', 'gender': 'boy'}
# {'name': 'Akseli', 'gender': 'boy'}
# {'name': 'Aksiniya', 'gender': 'girl'}
# {'name': 'Akua', 'gender': 'girl'}
# {'name': 'Akuba', 'gender': 'girl'}
# {'name': 'Akudo', 'gender': 'girl'}
# {'name': 'Akuji', 'gender': 'boy'}
# {'name': 'Akuma', 'gender': 'boy'}
# {'name': 'Akyla', 'gender': 'girl'}
# {'name': 'Akylah', 'gender': 'girl'}
# {'name': 'Al', 'gender': 'boy'}
# {'name': 'Ala', 'gender': 'girl'}
# {'name': 'Alaana', 'gender': 'girl'}
# {'name': 'Alabama', 'gender': 'girl'}
# {'name': 'Alabaster', 'gender': 'boy'}
# {'name': 'Aladdin', 'gender': 'boy'}
# {'name': 'Aladian', 'gender': 'boy'}
# {'name': 'Alafair', 'gender': 'girl'}
# {'name': 'Alafia', 'gender': 'girl'}
# {'name': 'Alah', 'gender': 'girl'}
# {'name': 'Alaia', 'gender': 'girl'}
# {'name': 'Alain', 'gender': 'boy'}
# {'name': 'Alaina', 'gender': 'girl'}
# {'name': 'Alaine', 'gender': 'girl'}
# {'name': 'Alaini', 'gender': 'girl'}
# {'name': 'Alainie', 'gender': 'girl'}
# {'name': 'Alair', 'gender': 'girl'}
# {'name': 'Alaira', 'gender': 'girl'}
# {'name': 'Alajandra', 'gender': 'girl'}
# (39, 65)
# https://nameberry.com/search?page=39&per_page=30&starts_with=A
# {'name': 'Alala', 'gender': 'girl'}
# {'name': 'Alalija', 'gender': 'girl'}
# {'name': 'Alamea', 'gender': 'girl'}
# {'name': 'Alameda', 'gender': 'girl'}
# {'name': 'Alamo', 'gender': 'boy'}
# {'name': 'Alan', 'gender': 'boy'}
# {'name': 'Alana', 'gender': 'girl'}
# {'name': 'Alanaa', 'gender': 'girl'}
# {'name': 'Alanae', 'gender': 'girl'}
# {'name': 'Alanah', 'gender': 'girl'}
# {'name': 'Aland', 'gender': 'boy'}
# {'name': 'Alandra', 'gender': 'girl'}
# {'name': 'Alandrah', 'gender': 'girl'}
# {'name': 'Alandria', 'gender': 'girl'}
# {'name': 'Alane', 'gender': 'girl'}
# {'name': 'Alanea', 'gender': 'girl'}
# {'name': 'Alaney', 'gender': 'girl'}
# {'name': 'Alani', 'gender': 'unisex'}
# {'name': 'Alani', 'gender': 'unisex'}
# {'name': 'Alania', 'gender': 'girl'}
# {'name': 'Alanie', 'gender': 'girl'}
# {'name': 'Alanis', 'gender': 'girl'}
# {'name': 'Alanna', 'gender': 'girl'}
# {'name': 'Alannah', 'gender': 'girl'}
# {'name': 'Alannie', 'gender': 'girl'}
# {'name': 'Alannis', 'gender': 'girl'}
# {'name': 'Alano', 'gender': 'boy'}
# {'name': 'Alanzo', 'gender': 'boy'}
# {'name': 'Alao', 'gender': 'boy'}
# {'name': 'Alara', 'gender': 'girl'}
# (40, 65)
# https://nameberry.com/search?page=40&per_page=30&starts_with=A
# {'name': 'Alard', 'gender': 'boy'}
# {'name': 'Alaric', 'gender': 'boy'}
# {'name': 'Alarich', 'gender': 'boy'}
# {'name': 'Alaricia', 'gender': 'girl'}
# {'name': 'Alarick', 'gender': 'boy'}
# {'name': 'Alarico', 'gender': 'boy'}
# {'name': 'Alarik', 'gender': 'boy'}
# {'name': 'Alart', 'gender': 'boy'}
# {'name': 'Alas', 'gender': 'boy'}
# {'name': 'Alasdair', 'gender': 'boy'}
# {'name': 'Alasdaire', 'gender': 'boy'}
# {'name': 'Alasdare', 'gender': 'boy'}
# {'name': 'Alaska', 'gender': 'girl'}
# {'name': 'Alasne', 'gender': 'girl'}
# {'name': 'Alastair', 'gender': 'boy'}
# {'name': 'Alastaire', 'gender': 'boy'}
# {'name': 'Alastar', 'gender': 'boy'}
# {'name': 'Alaster', 'gender': 'boy'}
# {'name': 'Alastrina', 'gender': 'girl'}
# {'name': 'Alastriona', 'gender': 'girl'}
# {'name': 'Alathea', 'gender': 'girl'}
# {'name': 'Alathia', 'gender': 'girl'}
# {'name': 'Alawna', 'gender': 'girl'}
# {'name': 'Alaxandra', 'gender': 'girl'}
# {'name': 'Alaxandria', 'gender': 'girl'}
# {'name': 'Alaxis', 'gender': 'girl'}
# {'name': 'Alaya', 'gender': 'girl'}
# {'name': 'Alayah', 'gender': 'girl'}
# {'name': 'Alayna', 'gender': 'girl'}
# (41, 65)
# https://nameberry.com/search?page=41&per_page=30&starts_with=A
# {'name': 'Alayne', 'gender': 'girl'}
# {'name': 'Alaysha', 'gender': 'girl'}
# {'name': 'Alaysia', 'gender': 'girl'}
# {'name': 'Alba', 'gender': 'girl'}
# {'name': 'Albain', 'gender': 'boy'}
# {'name': 'Alban', 'gender': 'boy'}
# {'name': 'Albana', 'gender': 'girl'}
# {'name': 'Albane', 'gender': 'girl'}
# {'name': 'Albani', 'gender': 'girl'}
# {'name': 'Albanie', 'gender': 'girl'}
# {'name': 'Albany', 'gender': 'unisex'}
# {'name': 'Albany', 'gender': 'unisex'}
# {'name': 'Albar', 'gender': 'boy'}
# {'name': 'Albaro', 'gender': 'boy'}
# {'name': 'Albee', 'gender': 'boy'}
# {'name': 'Albek', 'gender': 'boy'}
# {'name': 'Alben', 'gender': 'boy'}
# {'name': 'Albeni', 'gender': 'girl'}
# {'name': 'Alberik', 'gender': 'boy'}
# {'name': 'Albern', 'gender': 'boy'}
# {'name': 'Albert', 'gender': 'boy'}
# {'name': 'Alberta', 'gender': 'girl'}
# {'name': 'Alberte', 'gender': 'girl'}
# {'name': 'Albertha', 'gender': 'girl'}
# {'name': 'Alberthine', 'gender': 'girl'}
# {'name': 'Albertina', 'gender': 'girl'}
# {'name': 'Albertine', 'gender': 'girl'}
# {'name': 'Albertko', 'gender': 'boy'}
# {'name': 'Alberto', 'gender': 'boy'}
# (42, 65)
# https://nameberry.com/search?page=42&per_page=30&starts_with=A
# {'name': 'Alberts', 'gender': 'boy'}
# {'name': 'Albertus', 'gender': 'boy'}
# {'name': 'Albertyna', 'gender': 'girl'}
# {'name': 'Albertyne', 'gender': 'girl'}
# {'name': 'Albia', 'gender': 'girl'}
# {'name': 'Albie', 'gender': 'boy'}
# {'name': 'Albin', 'gender': 'boy'}
# {'name': 'Albina', 'gender': 'girl'}
# {'name': 'Albine', 'gender': 'girl'}
# {'name': 'Albinek', 'gender': 'boy'}
# {'name': 'Albinia', 'gender': 'girl'}
# {'name': 'Albinka', 'gender': 'girl'}
# {'name': 'Albino', 'gender': 'boy'}
# {'name': 'Albins', 'gender': 'boy'}
# {'name': 'Albion', 'gender': 'boy'}
# {'name': 'Albira', 'gender': 'girl'}
# {'name': 'Albrecht', 'gender': 'boy'}
# {'name': 'Albus', 'gender': 'boy'}
# ...
# (118, 67)
# https://nameberry.com/search?page=118&per_page=30&starts_with=C
# (119, 67)
# https://nameberry.com/search?page=119&per_page=30&starts_with=C
# (120, 67)
# https://nameberry.com/search?page=120&per_page=30&starts_with=C
# (121, 67)
# https://nameberry.com/search?page=121&per_page=30&starts_with=C
# (122, 67)
# https://nameberry.com/search?page=122&per_page=30&starts_with=C
# (123, 67)
# https://nameberry.com/search?page=123&per_page=30&starts_with=C
# (124, 67)
# https://nameberry.com/search?page=124&per_page=30&starts_with=C
# (125, 67)
# https://nameberry.com/search?page=125&per_page=30&starts_with=C
# (126, 67)
# https://nameberry.com/search?page=126&per_page=30&starts_with=C
# (127, 67)
# https://nameberry.com/search?page=127&per_page=30&starts_with=C
# (128, 67)
# https://nameberry.com/search?page=128&per_page=30&starts_with=C
# (129, 67)
# https://nameberry.com/search?page=129&per_page=30&starts_with=C
# (130, 67)
# https://nameberry.com/search?page=130&per_page=30&starts_with=C
# (131, 67)
# https://nameberry.com/search?page=131&per_page=30&starts_with=C
# (132, 67)
# https://nameberry.com/search?page=132&per_page=30&starts_with=C
# (133, 67)
# https://nameberry.com/search?page=133&per_page=30&starts_with=C
# (134, 67)
# https://nameberry.com/search?page=134&per_page=30&starts_with=C
# (135, 67)
# https://nameberry.com/search?page=135&per_page=30&starts_with=C
# (136, 67)
# https://nameberry.com/search?page=136&per_page=30&starts_with=C
# (137, 67)
# https://nameberry.com/search?page=137&per_page=30&starts_with=C
# (138, 67)
# https://nameberry.com/search?page=138&per_page=30&starts_with=C
# (139, 67)
# https://nameberry.com/search?page=139&per_page=30&starts_with=C
# (140, 67)
# https://nameberry.com/search?page=140&per_page=30&starts_with=C
# (141, 67)
# https://nameberry.com/search?page=141&per_page=30&starts_with=C
# (142, 67)
# https://nameberry.com/search?page=142&per_page=30&starts_with=C
# (143, 67)
# https://nameberry.com/search?page=143&per_page=30&starts_with=C
# (144, 67)
# https://nameberry.com/search?page=144&per_page=30&starts_with=C
# (145, 67)
# https://nameberry.com/search?page=145&per_page=30&starts_with=C
# (146, 67)
# https://nameberry.com/search?page=146&per_page=30&starts_with=C
# (147, 67)
# https://nameberry.com/search?page=147&per_page=30&starts_with=C
# (148, 67)
# https://nameberry.com/search?page=148&per_page=30&starts_with=C
# (149, 67)
# https://nameberry.com/search?page=149&per_page=30&starts_with=C
# (150, 67)
# https://nameberry.com/search?page=150&per_page=30&starts_with=C
# (151, 67)
# https://nameberry.com/search?page=151&per_page=30&starts_with=C
# (152, 67)
# https://nameberry.com/search?page=152&per_page=30&starts_with=C
# (153, 67)
# https://nameberry.com/search?page=153&per_page=30&starts_with=C
# (154, 67)
# https://nameberry.com/search?page=154&per_page=30&starts_with=C
# (155, 67)
# https://nameberry.com/search?page=155&per_page=30&starts_with=C
# (156, 67)
# https://nameberry.com/search?page=156&per_page=30&starts_with=C
# (157, 67)
# https://nameberry.com/search?page=157&per_page=30&starts_with=C
# (158, 67)
# https://nameberry.com/search?page=158&per_page=30&starts_with=C
# (159, 67)
# https://nameberry.com/search?page=159&per_page=30&starts_with=C
# (160, 67)
# https://nameberry.com/search?page=160&per_page=30&starts_with=C
# (161, 67)
# https://nameberry.com/search?page=161&per_page=30&starts_with=C
# (162, 67)
# https://nameberry.com/search?page=162&per_page=30&starts_with=C
# (163, 67)
# https://nameberry.com/search?page=163&per_page=30&starts_with=C
# (164, 67)
# https://nameberry.com/search?page=164&per_page=30&starts_with=C
# (165, 67)
# https://nameberry.com/search?page=165&per_page=30&starts_with=C
# (166, 67)
# https://nameberry.com/search?page=166&per_page=30&starts_with=C
# (167, 67)
# https://nameberry.com/search?page=167&per_page=30&starts_with=C
# (168, 67)
# https://nameberry.com/search?page=168&per_page=30&starts_with=C
# (169, 67)
# https://nameberry.com/search?page=169&per_page=30&starts_with=C
# (170, 67)
# https://nameberry.com/search?page=170&per_page=30&starts_with=C
# (171, 67)
# https://nameberry.com/search?page=171&per_page=30&starts_with=C
# (172, 67)
# https://nameberry.com/search?page=172&per_page=30&starts_with=C
# (173, 67)
# https://nameberry.com/search?page=173&per_page=30&starts_with=C
# (174, 67)
# https://nameberry.com/search?page=174&per_page=30&starts_with=C
# (175, 67)
# https://nameberry.com/search?page=175&per_page=30&starts_with=C
# (176, 67)
# https://nameberry.com/search?page=176&per_page=30&starts_with=C
# (177, 67)
# https://nameberry.com/search?page=177&per_page=30&starts_with=C
# (178, 67)
# https://nameberry.com/search?page=178&per_page=30&starts_with=C
# (179, 67)
# https://nameberry.com/search?page=179&per_page=30&starts_with=C
# (180, 67)
# https://nameberry.com/search?page=180&per_page=30&starts_with=C
# (181, 67)
# https://nameberry.com/search?page=181&per_page=30&starts_with=C
# (182, 67)
# https://nameberry.com/search?page=182&per_page=30&starts_with=C
# (183, 67)
# https://nameberry.com/search?page=183&per_page=30&starts_with=C
# (184, 67)
# https://nameberry.com/search?page=184&per_page=30&starts_with=C
# (185, 67)
# https://nameberry.com/search?page=185&per_page=30&starts_with=C
# (186, 67)
# https://nameberry.com/search?page=186&per_page=30&starts_with=C
# (187, 67)
# https://nameberry.com/search?page=187&per_page=30&starts_with=C
# (188, 67)
# https://nameberry.com/search?page=188&per_page=30&starts_with=C
# (189, 67)
# https://nameberry.com/search?page=189&per_page=30&starts_with=C
# (190, 67)
# https://nameberry.com/search?page=190&per_page=30&starts_with=C
# (191, 67)
# https://nameberry.com/search?page=191&per_page=30&starts_with=C
# (192, 67)
# https://nameberry.com/search?page=192&per_page=30&starts_with=C
# (193, 67)
# https://nameberry.com/search?page=193&per_page=30&starts_with=C
# (194, 67)
# https://nameberry.com/search?page=194&per_page=30&starts_with=C
# (195, 67)
# https://nameberry.com/search?page=195&per_page=30&starts_with=C
# (196, 67)
# https://nameberry.com/search?page=196&per_page=30&starts_with=C
# (197, 67)
# https://nameberry.com/search?page=197&per_page=30&starts_with=C
# (198, 67)
# https://nameberry.com/search?page=198&per_page=30&starts_with=C
# (199, 67)
# https://nameberry.com/search?page=199&per_page=30&starts_with=C
# (200, 67)
# https://nameberry.com/search?page=200&per_page=30&starts_with=C
# Done
# (1, 68)
# https://nameberry.com/search?page=1&per_page=30&starts_with=D
# {'name': 'Andre', 'gender': 'unisex'}
# {'name': 'Anton', 'gender': 'boy'}
# {'name': 'Arline', 'gender': 'girl'}
# {'name': 'Shawn', 'gender': 'unisex'}
# {'name': 'Shay', 'gender': 'unisex'}
# {'name': 'Nell', 'gender': 'girl'}
# {'name': 'Daan', 'gender': 'boy'}
# {'name': 'Daario', 'gender': 'boy'}
# {'name': 'Dabid', 'gender': 'boy'}
# {'name': 'Dabida', 'gender': 'girl'}
# {'name': 'Dabnee', 'gender': 'boy'}
# {'name': 'Dabney', 'gender': 'boy'}
# {'name': 'Dabnie', 'gender': 'boy'}
# {'name': 'Dabny', 'gender': 'boy'}
# {'name': 'Daccota', 'gender': 'boy'}
# {'name': 'Dace', 'gender': 'unisex'}
# {'name': 'Dace', 'gender': 'unisex'}
# {'name': 'Dacee', 'gender': 'girl'}
# {'name': 'Dacei', 'gender': 'girl'}
# {'name': 'Dacey', 'gender': 'unisex'}
# {'name': 'Dacey', 'gender': 'unisex'}
# {'name': 'Dacha', 'gender': 'boy'}
# {'name': 'Daci', 'gender': 'girl'}
# {'name': 'Dacia', 'gender': 'girl'}
# {'name': 'Dacian', 'gender': 'boy'}
# (2, 68)
# https://nameberry.com/search?page=2&per_page=30&starts_with=D
# {'name': 'Dacie', 'gender': 'girl'}
# {'name': 'Dacken', 'gender': 'boy'}
# {'name': 'Dacrius', 'gender': 'boy'}
# {'name': 'Dacso', 'gender': 'boy'}
# {'name': 'Dacy', 'gender': 'unisex'}
# {'name': 'Dacy', 'gender': 'unisex'}
# {'name': 'Dae', 'gender': 'girl'}
# {'name': 'Daedalus', 'gender': 'boy'}
# {'name': 'Daeja', 'gender': 'girl'}
# {'name': 'Dael', 'gender': 'girl'}
# {'name': 'Daelyn', 'gender': 'girl'}
# {'name': 'Daemon', 'gender': 'boy'}
# {'name': 'Daenerys', 'gender': 'girl'}
# {'name': 'Daeron', 'gender': 'boy'}
# {'name': 'Daffodil', 'gender': 'girl'}
# {'name': 'Daffy', 'gender': 'unisex'}
# {'name': 'Daffy', 'gender': 'unisex'}
# {'name': 'Daffydd', 'gender': 'boy'}
# {'name': 'Dafi', 'gender': 'boy'}
# {'name': 'Dafne', 'gender': 'girl'}
# {'name': 'Dafnee', 'gender': 'girl'}
# {'name': 'Dafneigh', 'gender': 'girl'}
# {'name': 'Dafny', 'gender': 'girl'}
# {'name': 'Dafydd', 'gender': 'boy'}
# {'name': 'Dag', 'gender': 'boy'}
# {'name': 'Dagan', 'gender': 'girl'}
# {'name': 'Dagger', 'gender': 'boy'}
# {'name': 'Dagget', 'gender': 'boy'}
# {'name': 'Daggett', 'gender': 'boy'}
# {'name': 'Dagmar', 'gender': 'girl'}
# (3, 68)
# https://nameberry.com/search?page=3&per_page=30&starts_with=D
# {'name': 'Dagmara', 'gender': 'girl'}
# {'name': 'Dagna', 'gender': 'girl'}
# {'name': 'Dagnanna', 'gender': 'girl'}
# {'name': 'Dagne', 'gender': 'girl'}
# {'name': 'Dagney', 'gender': 'girl'}
# {'name': 'Dagnie', 'gender': 'girl'}
# {'name': 'Dagny', 'gender': 'unisex'}
# {'name': 'Dagny', 'gender': 'unisex'}
# {'name': 'Dago', 'gender': 'boy'}
# {'name': 'Dagobert', 'gender': 'boy'}
# {'name': 'Dagomar', 'gender': 'girl'}
# {'name': 'Dagur', 'gender': 'boy'}
# {'name': 'Dagwood', 'gender': 'boy'}
# {'name': 'Dahey', 'gender': 'boy'}
# {'name': 'Dahlia', 'gender': 'girl'}
# {'name': 'Dahliah', 'gender': 'girl'}
# {'name': 'Dahliana', 'gender': 'girl'}
# {'name': 'Dahlina', 'gender': 'girl'}
# {'name': 'Dahlya', 'gender': 'girl'}
# {'name': 'Dahlye', 'gender': 'girl'}
# {'name': 'Dahra', 'gender': 'girl'}
# {'name': 'Dahrah', 'gender': 'girl'}
# {'name': 'Dahy', 'gender': 'boy'}
# {'name': 'Dai', 'gender': 'unisex'}
# {'name': 'Dai', 'gender': 'unisex'}
# {'name': 'Daia', 'gender': 'girl'}
# {'name': 'Daian', 'gender': 'boy'}
# {'name': 'Daiana', 'gender': 'girl'}
# {'name': 'Daianna', 'gender': 'girl'}
# {'name': 'Daibhidha', 'gender': 'girl'}
# (4, 68)
# https://nameberry.com/search?page=4&per_page=30&starts_with=D
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# /anaconda3/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      56
# ---> 57     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      58         af, socktype, proto, canonname, sa = res
#
# /anaconda3/lib/python3.7/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     300         # Add certificate verification
# --> 301         conn = self._new_conn()
#     302         hostname = self.host
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     167             raise NewConnectionError(
# --> 168                 self, "Failed to establish a new connection: %s" % e)
#     169
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x118498710>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# /anaconda3/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     397         if new_retry.is_exhausted():
# --> 398             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     399
#
# MaxRetryError: HTTPSConnectionPool(host='nameberry.com', port=443): Max retries exceeded with url: /search?page=4&per_page=30&starts_with=D (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x118498710>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-2-262bca81eb88> in <module>
#      42
#      43 for char in range(65,92):
# ---> 44     crawler(char)
#
# <ipython-input-2-262bca81eb88> in crawler(year)
#       9         url = 'https://nameberry.com/search?page='+str(page)+'&per_page=30&starts_with='+(chr(char))
#      10         print(url)
# ---> 11         source_code = requests.get(url, allow_redirects=False)
#      12
#      13         soup = BeautifulSoup(source_code.text,'html.parser')
#
# /anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# /anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='nameberry.com', port=443): Max retries exceeded with url: /search?page=4&per_page=30&starts_with=D (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x118498710>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
