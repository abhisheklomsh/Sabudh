# %%
import sys
correct_word = input()
correct_word = list(correct_word)
guess_track=[]
for item in range(len(correct_word)):
    guess_track.append("_")

print(guess_track)
tracked = []
counter=0
print(correct_word)
flag=1
life=6
# Out:
# Hangman
# ['_', '_', '_', '_', '_', '_', '_']
# ['H', 'a', 'n', 'g', 'm', 'a', 'n']

# %%
while (len(correct_word) > 0 and flag == 1 and life > 0):
    guess_char=input("enter your guess")
    life_flag=1
    for i in range(len(correct_word)):
        #print("turn is",i)
        
        if guess_track == correct_word:
            print("you won")
            flag=0
            break
            
        elif guess_char == correct_word[i]:
            tracked.append(i)
            guess_track[i]=correct_word[i]
            print(guess_track)
            life_flag=0
            #print(i)
            #print(correct_word)
            #print(str(guess_track))
            
        elif guess_track == correct_word:
            print("you won")
            flag=0
            break
        elif (guess_char != correct_word[i] and life_flag==1):
            life-=1
            print(life," lifes left")
            print("Out of lives, better luck next time!")
        else:
            pass
# Out:
# enter your guessH
# ['H', '_', '_', '_', '_', '_', '_']
# enter your guessa
# 5  lifes left
# Out of lives, better luck next time!
# ['H', 'a', '_', '_', '_', '_', '_']
# ['H', 'a', '_', '_', '_', 'a', '_']
# enter your guessn
# 4  lifes left
# Out of lives, better luck next time!
# 3  lifes left
# Out of lives, better luck next time!
# ['H', 'a', 'n', '_', '_', 'a', '_']
# ['H', 'a', 'n', '_', '_', 'a', 'n']
# enter your guessg
# 2  lifes left
# Out of lives, better luck next time!
# 1  lifes left
# Out of lives, better luck next time!
# 0  lifes left
# Out of lives, better luck next time!
# ['H', 'a', 'n', 'g', '_', 'a', 'n']
