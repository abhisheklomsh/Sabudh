# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen('https://www.nytimes.com/')

# %%
bs = BeautifulSoup(html, "html.parser")

# %%
bs.find_all(['h1', 'h2','h3','h4','h5','h6'])
# Out:
# [<h2 class="css-9ywo2s esl82me2">Listen to ‘The Daily’</h2>,
#  <h2 class="css-9ywo2s esl82me2">In the ‘Smarter Living’ Newsletter</h2>,
#  <h2 class="css-9ywo2s esl82me2">The Neediest Cases Fund</h2>,
#  <h2 class="css-bzeb53 esl82me2"><span>Trump Escalates Border Wall Fight in Speech to the Nation</span></h2>,
#  <h2 class="css-6h3ud0 esl82me2">Read the full transcript of Mr. Trump’s remarks and the Democratic response.</h2>,
#  <h2 class="css-6h3ud0 esl82me2">Fact-Checking Trump’s Address on Border Security</h2>,
#  <h3>Shutdown Fallout</h3>,
#  <h2 class="css-bzeb53 esl82me2"><span>On the Border, Little Enthusiasm for a Wall</span></h2>,
#  <h2 class="css-6h3ud0 esl82me2">It’s Payday for Many Federal Workers. One Problem: There’s No Paycheck.</h2>,
#  <h2 class="css-6h3ud0 esl82me2">See how the effects of the government shutdown are piling up.</h2>,
#  <h3>TRUMP AND RUSSIA</h3>,
# ...

# %%
for single_title in bs.find_all(['h1', 'h2','h3','h4','h5','h6']):
    print(single_title.get_text())
# Out:
# Listen to ‘The Daily’
# In the ‘Smarter Living’ Newsletter
# The Neediest Cases Fund
# Trump Escalates Border Wall Fight in Speech to the Nation
# Read the full transcript of Mr. Trump’s remarks and the Democratic response.
# Fact-Checking Trump’s Address on Border Security
# Shutdown Fallout
# On the Border, Little Enthusiasm for a Wall
# It’s Payday for Many Federal Workers. One Problem: There’s No Paycheck.
# See how the effects of the government shutdown are piling up.
# TRUMP AND RUSSIA
# Manafort Gave Poll Data to Russian Tied to Intelligence, Prosecutors Say
# Russian in Trump Tower Meeting Is Charged in Case That Shows Kremlin Links
# The Supreme Court refused to intercede in a mysterious fight over a sealed subpoena that may be part of the Mueller inquiry.
# U.S. Foreign policy
# Erdogan Snubs Bolton Over Comments That Turkey Must Protect Kurds
# China Offers Trump a Trade Peace Deal. It May Not Be Enough.
# ...

# %%
titles = bs.find_all(['h1', 'h2','h3','h4','h5','h6'])

# %%
titles.get_text()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-94cf058fd017> in <module>()
# ----> 1 titles.get_text()
#
# /Users/abhisheklomsh/anaconda/lib/python3.6/site-packages/bs4/element.py in __getattr__(self, key)
#    1805     def __getattr__(self, key):
#    1806         raise AttributeError(
# -> 1807             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1808         )
#
# AttributeError: ResultSet object has no attribute 'get_text'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
#comic = bs.find_all("h2", {"class": "css-9ywo2s esl82me2"})

# %%
bs.getText("h1", {"class": "css-9ywo2s esl82me2"})
# Out:
# 'Breaking News, World News & Multimedia - The New York Timesh1(function() {\n    var xhr = new XMLHttpRequest();\n    xhr.withCredentials = true;\n    xhr.open(\'POST\', \'https://samizdat-graphql.nytimes.com/graphql/v2\', true);\n    xhr.setRequestHeader(\'Content-Type\', \'application/json\');\n    xhr.setRequestHeader(\'nyt-app-type\', \'project-vi\');\n    xhr.setRequestHeader(\'nyt-app-version\', \'0.0.3\');\n    xhr.setRequestHeader(\'nyt-token\',   \'\');\n    xhr.send(\'{"operationName":"UserQuery","variables":{},"query":"   query UserQuery {     user {       __typename       profile {      
# ...

# %%
print('List all the titles :', *titles, sep='\n')
# Out:
# List all the titles :
# <h2 class="css-9ywo2s esl82me2">Listen to ‘The Daily’</h2>
# <h2 class="css-9ywo2s esl82me2">In the ‘Smarter Living’ Newsletter</h2>
# <h2 class="css-9ywo2s esl82me2">The Neediest Cases Fund</h2>
# <h2 class="css-bzeb53 esl82me2"><span>Trump Escalates Border Wall Fight in Speech to the Nation</span></h2>
# <h2 class="css-6h3ud0 esl82me2">Read the full transcript of Mr. Trump’s remarks and the Democratic response.</h2>
# <h2 class="css-6h3ud0 esl82me2">Fact-Checking Trump’s Address on Border Security</h2>
# <h3>Shutdown Fallout</h3>
# <h2 class="css-bzeb53 esl82me2"><span>On the Border, Little Enthusiasm for a Wall</span></h2>
# <h2 class="css-6h3ud0 esl82me2">It’s Payday for Many Federal Workers. One Problem: There’s No Paycheck.</h2>
# <h2 class="css-6h3ud0 esl82me2">See how the effects of the government shutdown are piling up.</h2>
# <h3>TRUMP AND RUSSIA</h3>
# ...
