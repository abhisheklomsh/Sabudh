# %%
import cv2
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-691a1fb46861> in <module>()
# ----> 1 import cv2
#       2 import numpy as np
#       3
#       4 import matplotlib.pyplot as plt
#       5 get_ipython().magic(u'matplotlib inline')
#
# ImportError: No module named cv2

# %%
#Open a simple image
m=cv2.imread("C:/Users/User/Desktop/m.jpg")
img_HSV = cv2.cvtColor(m, cv2.COLOR_BGR2HSV)
#skin color range for hsv color space 
HSV_mask = cv2.inRange(img_HSV, (0, 80, 20), (25, 255, 255)) 
target = cv2.bitwise_and(m,m, mask=HSV_mask)
cv2.imwrite('segmented out region.jpg',target)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-dc822fdb16a1> in <module>()
#       1 #Open a simple image
# ----> 2 m=cv2.imread("C:/Users/User/Desktop/m.jpg")
#       3 img_HSV = cv2.cvtColor(m, cv2.COLOR_BGR2HSV)
#       4 #skin color range for hsv color space
#       5 HSV_mask = cv2.inRange(img_HSV, (0, 80, 20), (25, 255, 255))
#
# NameError: name 'cv2' is not defined

# %%
plt.imshow(cv2.cvtColor(m, cv2.COLOR_BGR2RGB))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-025079a0bfa0> in <module>()
# ----> 1 plt.imshow(cv2.cvtColor(m, cv2.COLOR_BGR2RGB))
#
# NameError: name 'plt' is not defined

# %%
plt.imshow(cv2.cvtColor(target, cv2.COLOR_BGR2RGB))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-7d57c358399d> in <module>()
# ----> 1 plt.imshow(cv2.cvtColor(target, cv2.COLOR_BGR2RGB))
#
# NameError: name 'plt' is not defined

# %%
contours,hierarchy  = cv2.findContours(cv2.cvtColor(target, cv2.COLOR_BGR2GRAY), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-deba2d0c5ea9> in <module>()
# ----> 1 contours,hierarchy  = cv2.findContours(cv2.cvtColor(target, cv2.COLOR_BGR2GRAY), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
#
# NameError: name 'cv2' is not defined

# %%
cv2.imwrite('oranges with bounding boxes.jpg',m)
plt.imshow(m)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-e48723d77e31> in <module>()
# ----> 1 cv2.imwrite('oranges with bounding boxes.jpg',m)
#       2 plt.imshow(m)
#
# NameError: name 'cv2' is not defined

# %%
bounding_boxes = []
threshold = 75
ar=[]
imgwithbox = m.copy()
for c in contours:
    area = cv2.contourArea(c)
    if area >threshold:
        [x,y,w,h]=cv2.boundingRect(c)
        bounding_boxes.append([x,y,w,h])
        print([x,y,w,h])
        area_rect=w*h
        print(area_rect)
        ar.append(area_rect)
        cv2.rectangle(imgwithbox,(x,y),(x+w,y+h),(0,255,0),2)

print(len(bounding_boxes))
print(ar)
total_area=sum(ar)
print(total_area)
avg_rect= total_area/len(bounding_boxes)
print(avg_rect)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-2c3d70681704> in <module>()
#       2 threshold = 75
#       3 ar=[]
# ----> 4 imgwithbox = m.copy()
#       5 for c in contours:
#       6     area = cv2.contourArea(c)
#
# NameError: name 'm' is not defined

# %%
q=np.asarray(ar)
print(q)
no_of_oranges = q/avg_rect
print(no_of_oranges)
# Out:
#   File "<ipython-input-16-97ceba3bdd8b>", line 7
#     else if no_of_oranges > 0.3 & < 1:
#           ^
# SyntaxError: invalid syntax

# %%
O_MIN = np.array([0, 80, 20], np.uint8)
O_MAX = np.array([25, 255, 255], np.uint8)

dst = cv2.inRange(imgwithbox, O_MIN, O_MAX)
orange_pixel = cv2.countNonZero(dst)
print('The number of orange pixels is: ' + str(orange_pixel))
# Out:
# The number of orange pixels is: 2582

# %%
cv2.rectangle(m,(107,470),(107+64,470+30),(0,255,0),2)
plt.imshow(m)

# %%
cv2.rectangle(m,(558,385),(558+11,385+15),(0,255,0),2)
plt.imshow(m)

# %%
cv2.rectangle(m,(781,622),(781+14,622+15),(0,255,0),2)
plt.imshow(m)

# %%
count_boxes = []
threshold = 75
imgwithbox = m.copy()
for c in contours:
    area = cv2.contourArea(c)
    if area >threshold:
        if no_of_oranges < 0.3:
            count=0
    elif no_of_oranges => 0.3 & <=1:
            count=1
    elif no_of_oranges => 1 & <= 2:
            count=2
    [x,y,w,h]=cv2.boundingRect(c)
    bounding_boxes.append([x,y,w,h])
    cv2.rectangle(imgwithbox,(x,y),(x+w,y+h),(0,255,0),2)

print(count)
# Out:
#   File "<ipython-input-21-839be3918779>", line 9
#     elif no_of_oranges > 0.3 & < 1:
#                                ^
# SyntaxError: invalid syntax
