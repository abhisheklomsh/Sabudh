# %%
"""Here I am trying to extract equation within bracket and solve them"""

# %%
import re
import numpy as np
s="(tanx)(sinx)(cosX)"
#a=re.search('\(([^)]+)', s).groups()
r = re.findall(r'\((\w+)\)', s)

# %%
r
# Out:
# ['tanx', 'sinx', 'cosX']

# %%
from sympy import Symbol, Derivative
s = "sin(x)"
x= Symbol('x')

deriv= Derivative(s, x)
deriv.doit()
# Out:
# cos(x)

# %%
from sympy import Symbol, Derivative

x= Symbol('x')
s = "((3+3)/3)"
function= re.findall(r'\(\w+\)', s)
print(eval(s))
deriv= Derivative(s, x)
deriv.doit()
# Out:
# 2.0
# 0
